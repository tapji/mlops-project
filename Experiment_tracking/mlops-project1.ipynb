# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd
import pickle
from sklearn.impute import SimpleImputer
from sklearn.feature_extraction import DictVectorizer

# for regression models
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso

# To help with data visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

#performance
from sklearn.metrics import mean_squared_error

# To supress warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("mlops-project")
# Out:
# 2023/07/24 08:20:00 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2023/07/24 08:20:00 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade 3500859a5d39 -> 7f2a7d5fae7d, add datasets inputs input_tags tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# <Experiment: artifact_location='/home/tapji/.conda/mlops-project/mlruns/1', creation_time=1689852646451, experiment_id='1', last_update_time=1689852646451, lifecycle_stage='active', name='mlops-project', tags={}>

# %% [markdown]
# ### Importing dataset

# %%
def read_dataframe(filename: str):
    df = pd.read_csv(filename, encoding='iso-8859-1')
    
    # Remove '£' and ',' sign from 'Total Cost/ 10000 miles' column and convert to numeric values
    df['Annual fuel Cost 10000 Miles'] = df['Annual fuel Cost 10000 Miles'].str.replace('£', '')
    df['Annual fuel Cost 10000 Miles'] = df['Annual fuel Cost 10000 Miles'].str.replace(',', '').astype(int)
    df['Annual Electricity cost / 10000 miles'] = df['Annual Electricity cost / 10000 miles'].str.replace('£', '')
    df['Annual Electricity cost / 10000 miles'] = df['Annual Electricity cost / 10000 miles'].str.replace(',', '').astype(int)
    df['Total cost / 10000 miles'] = df['Total cost / 10000 miles'].str.replace('£', '')
    df['Total cost / 10000 miles'] = df['Total cost / 10000 miles'].str.replace(',', '').astype(int)

    # dropping irrelevant features
    df.drop(['Manufacturer', 'Model', 'Description','Transmission', 'Engine Power (Kw)', 'Engine Power (PS)',
      'Electric energy consumption Miles/kWh', 'wh/km', 'Diesel VED Supplement', 'Testing Scheme', 'Euro Standard', 'Maximum range (Miles)',
      'WLTP Imperial Low', 'WLTP Imperial Medium', 'WLTP Imperial High','WLTP Imperial Extra High', 'WLTP Imperial Combined',
      'WLTP Imperial Combined (Weighted)', 'WLTP Metric Low','WLTP Metric Medium', 'WLTP Metric High', 'WLTP Metric Extra High',
      'WLTP Metric Combined', 'WLTP Metric Combined (Weighted)','WLTP CO2 Weighted', 'Equivalent All Electric Range Miles', 'Equivalent All Electric Range KM',
      'THC Emissions [mg/km]', 'Electric Range City Miles', 'RDE NOx Urban', 'Powertrain', 'Annual fuel Cost 10000 Miles', 'Electric Range City Km', 'Noise Level dB(A)',
      'RDE NOx Combined', 'Emissions CO [mg/km]', 'Emissions NOx [mg/km]', 'THC + NOx Emissions [mg/km]', 'Annual Electricity cost / 10000 miles', 'Maximum range (Km)'], axis=1, inplace=True)

    # inputting missing values
    columns_to_impute = ['WLTP CO2', 'Particulates [No.] [mg/km]']
    
    imputer = SimpleImputer(strategy='mean')
    df[columns_to_impute] = imputer.fit_transform(df[columns_to_impute])

   # Converting object data type to categorical

    for feature in df.columns: 
      if df[feature].dtype == 'object': 
         df[feature] = pd.Categorical(df[feature])# Replace strings with an integer

    # Renaming columns
    
    df.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

    return df

# %%
df = read_dataframe('./data/emission_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4625 entries, 0 to 4624
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Engine_Capacity             4625 non-null   int64
#  1   Fuel_Type                   4625 non-null   category
#  2   WLTP_CO2                    4625 non-null   float64
#  3   Total_cost_/_10000_miles    4625 non-null   int64
#  4   Particulates_[No.]_[mg/km]  4625 non-null   float64
# dtypes: category(1), float64(2), int64(2)
# memory usage: 149.5 KB

# %%
def train_test(df):
    # independent variables
    X = df.drop(["WLTP_CO2"], axis=1)
    # dependent variable 
    y = df["WLTP_CO2"]

    # Adding intercept to the dataset
    X = pd.get_dummies(X, drop_first=True)   
    X = sm.add_constant(X)
    
    # Splitting X and y into train and test sets in a 70:30 ratio
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.30, random_state=1
    )
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = train_test(df)

# %%
# Training the model

def ols_regression(X_train, X_test, y_train, y_test): 
    mlflow.end_run()
    with mlflow.start_run():
        mlflow.set_tag("model", "ols_regression")
        olsmod = sm.OLS(y_train, X_train)
        olsres = olsmod.fit()
    
        # Identify columns in the training and test dataset
        train_columns = set(X_train.columns)
        test_columns = set(X_test.columns)
    
        # Compare columns training and testing dataset columns
        columns_to_drop = test_columns - train_columns
    
        # Drop columns from the test dataset
        X_test.drop(columns=columns_to_drop, inplace=True)

        # Making predictions on the test set
        y_pred = olsres.predict(X_test)
        rmse1 = np.sqrt(mean_squared_error(y_train, olsres.fittedvalues))
        rmse2 = np.sqrt(mean_squared_error(y_test, y_pred))
        mlflow.log_metric("rmse", rmse2)
    # return the regression summary as a string
        with open("models/preprocessor.b", "wb") as f_out:
            pickle.dump(olsres, f_out)
            mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")
            mlflow.sklearn.log_model(olsres, "OLS_Model")
    return rmse1, rmse2, olsres

# %%
rmse1, rmse2, olres = ols_regression(X_train, X_test, y_train, y_test)

# %%
print(rmse1, rmse2)
# Out:
# 17.613735102497987 13.022063151691114

# %%
print(olres.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               WLTP_CO2   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     3657.
# Date:                Fri, 21 Jul 2023   Prob (F-statistic):               0.00
# Time:                        10:51:32   Log-Likelihood:                -13879.
# No. Observations:                3237   AIC:                         2.778e+04
# Df Residuals:                    3226   BIC:                         2.785e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             13.6838      1.320     10.366      0.000      11.095      16.272
# Engine_Capacity                    0.0041      0.001      6.546      0.000       0.003       0.005
# Total_cost_/_10000_miles           0.0776      0.001     77.328      0.000       0.076       0.080
# Particulates_[No.]_[mg/km]         2.6517      0.671      3.952      0.000       1.336       3.967
# Fuel_Type_Diesel Electric         -0.2312      2.681     -0.086      0.931      -5.488       5.026
# Fuel_Type_Electricity            -76.9427      1.669    -46.113      0.000     -80.214     -73.671
# Fuel_Type_Electricity / Diesel  -139.7103      7.242    -19.293      0.000    -153.909    -125.512
# Fuel_Type_Electricity / Petrol   -58.6827      1.939    -30.262      0.000     -62.485     -54.881
# Fuel_Type_Petrol                 -10.0523      0.805    -12.492      0.000     -11.630      -8.474
# Fuel_Type_Petrol / LPG            54.0132      2.852     18.941      0.000      48.422      59.604
# Fuel_Type_Petrol Electric        -11.6965      1.033    -11.324      0.000     -13.722      -9.671
# ==============================================================================
# Omnibus:                     1198.404   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           354310.562
# Skew:                          -0.441   Prob(JB):                         0.00
# Kurtosis:                      54.246   Cond. No.                     6.26e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.26e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4625 entries, 0 to 4624
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Engine_Capacity             4625 non-null   int64
#  1   Fuel_Type                   4625 non-null   category
#  2   WLTP_CO2                    4625 non-null   float64
#  3   Total_cost_/_10000_miles    4625 non-null   int64
#  4   Particulates_[No.]_[mg/km]  4625 non-null   float64
# dtypes: category(1), float64(2), int64(2)
# memory usage: 149.5 KB

# %%
def lasso_prep(df):
    
    # Splitting X and y into train and test sets in a 70:30 ratio
     # independent variables
    X = df.drop(["WLTP_CO2"], axis=1)
    # dependent variable 
    y = df["WLTP_CO2"]
    
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.30, random_state=1)
    
    categorical = ['Fuel_Type']
    numerical = ['Engine_Capacity', 'Total_cost_/_10000_miles', 'Particulates_[No.]_[mg/km]']
    dv = DictVectorizer()
    train_dicts = X_train[categorical + numerical].to_dict(orient='records')
    X_train = dv.fit_transform(train_dicts)
    test_dicts = X_test[categorical + numerical].to_dict(orient='records')
    X_test = dv.transform(test_dicts)

    return X_train, X_test, y_train, y_test

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((olres), f_out)

# %%
X_train, X_test, y_train, y_test = lasso_prep(df)

# %%
def lasso_regression(X_train, X_test, y_train, y_test):
    
    mlflow.end_run()
    with mlflow.start_run():
    
        mlflow.set_tag('Data Scientist', 'Tapji')
        mlflow.log_param('train-data-path', './data/emission_data.csv')
        alpha = 0.0001
        mlflow.log_param('alpha', alpha)

    
        target = 'WLTP_CO2'
        y_train = y_train.values.ravel()  # Convert target to a 1-dimensional array
        y_test = y_test.values.ravel()    # Convert target to a 1-dimensional array

        lr = Lasso(alpha)  # Assuming you want to use a specific alpha value

        # Fit the Lasso model to the training data
        lr.fit(X_train, y_train)

        # Making predictions on the test set
        y_pred = lr.predict(X_test)

        # Calculate RMSE for training set
        rmse3 = np.sqrt(mean_squared_error(y_train, lr.predict(X_train)))

        # Calculate RMSE for test set
        rmse4 = np.sqrt(mean_squared_error(y_test, y_pred))
        mlflow.log_metric('rmse_training', rmse3)
        mlflow.log_metric('rmse_test', rmse4)
        
        mlflow.log_artifact(local_path="models/lin_reg.bin", artifact_path="models_pickle/lin_reg.bin")
    return rmse3, rmse4, lr

# %%
rmse3, rmse4, lr = lasso_regression(X_train, X_test, y_train, y_test)

# %%
print(rmse3, rmse4)
# Out:
# 17.613735319974264 13.022177378370465

# %% [markdown]
# #### Using XGBoost for Training

# %%
# XGBoost
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
test = xgb.DMatrix(X_test, label=y_test)

# %%
def objective(params):
    
    mlflow.end_run()
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(test, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(test)
        rmse = mean_squared_error(y_test, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [18:18:12] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:152.31629
# [1]	validation-rmse:144.24840
# [2]	validation-rmse:136.62095
# [3]	validation-rmse:129.38080
# [4]	validation-rmse:122.54012
# [5]	validation-rmse:116.04860
# [6]	validation-rmse:109.94951
# [7]	validation-rmse:104.17865
# [8]	validation-rmse:98.68816
# [9]	validation-rmse:93.50258
# [10]	validation-rmse:88.59894
# [11]	validation-rmse:83.96698
# [12]	validation-rmse:79.56124
# [13]	validation-rmse:75.41126
# [14]	validation-rmse:71.47752
# [15]	validation-rmse:67.76880
# [16]	validation-rmse:64.23996
# [17]	validation-rmse:60.92008
# [18]	validation-rmse:57.79015
# [19]	validation-rmse:54.81416
# [20]	validation-rmse:52.00855
# [21]	validation-rmse:49.33283
# [22]	validation-rmse:46.81036
# [23]	validation-rmse:44.42997
# [24]	validation-rmse:42.16484
# [25]	validation-rmse:40.03856
# [26]	validation-rmse:38.01355
# [27]	validation-rmse:36.11768
# [28]	validation-rmse:34.33015
# [29]	validation-rmse:32.62508
# [30]	validation-rmse:31.02271
# [31]	validation-rmse:29.51164
# [32]	validation-rmse:28.08652
# [33]	validation-rmse:26.74287
# [34]	validation-rmse:25.47709
# [35]	validation-rmse:24.27804
# [36]	validation-rmse:23.15481
# [37]	validation-rmse:22.09223
# [38]	validation-rmse:21.09577
# [39]	validation-rmse:20.15502
# [40]	validation-rmse:19.27461
# [41]	validation-rmse:18.44462
# [42]	validation-rmse:17.66712
# [43]	validation-rmse:16.93571
# [44]	validation-rmse:16.24849
# [45]	validation-rmse:15.60885
# [46]	validation-rmse:15.00174
# [47]	validation-rmse:14.44706
# [48]	validation-rmse:13.93232
# [49]	validation-rmse:13.45259
# [50]	validation-rmse:13.00370
# [51]	validation-rmse:12.58164
# [52]	validation-rmse:12.19169
# [53]	validation-rmse:11.84115
# [54]	validation-rmse:11.50687
# [55]	validation-rmse:11.20516
# [56]	validation-rmse:10.91255
# [57]	validation-rmse:10.64750
# [58]	validation-rmse:10.40352
# [59]	validation-rmse:10.18386
# [60]	validation-rmse:9.97800
# [61]	validation-rmse:9.79018
# [62]	validation-rmse:9.61822
# [63]	validation-rmse:9.46163
# [64]	validation-rmse:9.31845
# [65]	validation-rmse:9.18406
# [66]	validation-rmse:9.06434
# [67]	validation-rmse:8.94788
# [68]	validation-rmse:8.84282
# [69]	validation-rmse:8.75109
# [70]	validation-rmse:8.66077
# [71]	validation-rmse:8.58054
# [72]	validation-rmse:8.50589
# [73]	validation-rmse:8.43908
# [74]	validation-rmse:8.37479
# [75]	validation-rmse:8.32070
# [76]	validation-rmse:8.26702
# [77]	validation-rmse:8.22401
# [78]	validation-rmse:8.18401
# [79]	validation-rmse:8.14634
# [80]	validation-rmse:8.10693
# [81]	validation-rmse:8.07919
# [82]	validation-rmse:8.04670
# [83]	validation-rmse:8.01807
# [84]	validation-rmse:7.99269
# [85]	validation-rmse:7.96993
# [86]	validation-rmse:7.94903
# [87]	validation-rmse:7.92937
# [88]	validation-rmse:7.91175
# [89]	validation-rmse:7.89728
# [90]	validation-rmse:7.88352
# [91]	validation-rmse:7.87668
# [92]	validation-rmse:7.86333
# [93]	validation-rmse:7.84996
# [94]	validation-rmse:7.83963
# [95]	validation-rmse:7.82685
# [96]	validation-rmse:7.81665
# [97]	validation-rmse:7.80525
# [98]	validation-rmse:7.79605
# [99]	validation-rmse:7.78732
# [100]	validation-rmse:7.78077
# [101]	validation-rmse:7.77387
# [102]	validation-rmse:7.76755
# [103]	validation-rmse:7.76531
# [104]	validation-rmse:7.75929
# [105]	validation-rmse:7.75499
# [106]	validation-rmse:7.75076
# [107]	validation-rmse:7.74407
# [108]	validation-rmse:7.74073
# [109]	validation-rmse:7.73577
# [110]	validation-rmse:7.73090
# [111]	validation-rmse:7.72760
# [112]	validation-rmse:7.72265
# [113]	validation-rmse:7.72056
# [114]	validation-rmse:7.71747
# [115]	validation-rmse:7.71572
# [116]	validation-rmse:7.71362
# [117]	validation-rmse:7.71264
# [118]	validation-rmse:7.71143
# [119]	validation-rmse:7.70942
# [120]	validation-rmse:7.71011
# [121]	validation-rmse:7.70892
# [122]	validation-rmse:7.70994
# [123]	validation-rmse:7.71117
# [124]	validation-rmse:7.70936
# [125]	validation-rmse:7.70628
# [126]	validation-rmse:7.70398
# [127]	validation-rmse:7.70028
# [128]	validation-rmse:7.70034
# [129]	validation-rmse:7.70119
# [130]	validation-rmse:7.70074
# [131]	validation-rmse:7.70142
# [132]	validation-rmse:7.69934
# [133]	validation-rmse:7.69775
# [134]	validation-rmse:7.69833
# [135]	validation-rmse:7.69814
# [136]	validation-rmse:7.70128
# [137]	validation-rmse:7.69864
# [138]	validation-rmse:7.70166
# [139]	validation-rmse:7.70126
# [140]	validation-rmse:7.70575
# [141]	validation-rmse:7.70912
# [142]	validation-rmse:7.70667
# [143]	validation-rmse:7.71048
# [144]	validation-rmse:7.71156
# [145]	validation-rmse:7.71266
# [146]	validation-rmse:7.71185
# [147]	validation-rmse:7.71423
# [148]	validation-rmse:7.71319
# [149]	validation-rmse:7.71131
# [150]	validation-rmse:7.71169
# [151]	validation-rmse:7.71421
# [152]	validation-rmse:7.71606
# [153]	validation-rmse:7.71463
# [154]	validation-rmse:7.71645
# [155]	validation-rmse:7.71555
# [156]	validation-rmse:7.71590
# [157]	validation-rmse:7.71651
# [158]	validation-rmse:7.71608
# [159]	validation-rmse:7.71340
# [160]	validation-rmse:7.71326
# [161]	validation-rmse:7.71493
# [162]	validation-rmse:7.71545
# [163]	validation-rmse:7.71343
# [164]	validation-rmse:7.71394
# [165]	validation-rmse:7.71344
# [166]	validation-rmse:7.71276
# [167]	validation-rmse:7.71238
# [168]	validation-rmse:7.71364
# [169]	validation-rmse:7.71354
# [170]	validation-rmse:7.71462
# [171]	validation-rmse:7.71469
# [172]	validation-rmse:7.71326
# [173]	validation-rmse:7.71411
# [174]	validation-rmse:7.71527
# [175]	validation-rmse:7.71636
# [176]	validation-rmse:7.71305
# [177]	validation-rmse:7.71306
# [178]	validation-rmse:7.71255
# [179]	validation-rmse:7.71343
# [180]	validation-rmse:7.71478
# [181]	validation-rmse:7.71563
# [182]	validation-rmse:7.71641
# [183]	validation-rmse:7.71620
# [18:18:15] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:148.31486
# [1]	validation-rmse:136.75486
# [2]	validation-rmse:126.10291
# [3]	validation-rmse:116.28862
# [4]	validation-rmse:107.23645
# [5]	validation-rmse:98.90049
# [6]	validation-rmse:91.22030
# [7]	validation-rmse:84.14511
# [8]	validation-rmse:77.63484
# [9]	validation-rmse:71.63450
# [10]	validation-rmse:66.09978
# [11]	validation-rmse:61.00933
# [12]	validation-rmse:56.32279
# [13]	validation-rmse:52.01370
# [14]	validation-rmse:48.04681
# [15]	validation-rmse:44.40095
# [16]	validation-rmse:41.04962
# [17]	validation-rmse:37.97097
# [18]	validation-rmse:35.14356
# [19]	validation-rmse:32.54739
# [20]	validation-rmse:30.16849
# [21]	validation-rmse:27.98927
# [22]	validation-rmse:25.99568
# [23]	validation-rmse:24.17207
# [24]	validation-rmse:22.50534
# [25]	validation-rmse:20.98985
# [26]	validation-rmse:19.61024
# [27]	validation-rmse:18.35688
# [28]	validation-rmse:17.22181
# [29]	validation-rmse:16.19663
# [30]	validation-rmse:15.27067
# [31]	validation-rmse:14.43958
# [32]	validation-rmse:13.69311
# [33]	validation-rmse:13.02680
# [34]	validation-rmse:12.43367
# [35]	validation-rmse:11.90650
# [36]	validation-rmse:11.44220
# [37]	validation-rmse:11.03177
# [38]	validation-rmse:10.67203
# [39]	validation-rmse:10.35722
# [40]	validation-rmse:10.08151
# [41]	validation-rmse:9.83873
# [42]	validation-rmse:9.63341
# [43]	validation-rmse:9.45398
# [44]	validation-rmse:9.30041
# [45]	validation-rmse:9.16900
# [46]	validation-rmse:9.05600
# [47]	validation-rmse:8.95908
# [48]	validation-rmse:8.87655
# [49]	validation-rmse:8.80612
# [50]	validation-rmse:8.74605
# [51]	validation-rmse:8.69562
# [52]	validation-rmse:8.65235
# [53]	validation-rmse:8.61635
# [54]	validation-rmse:8.58592
# [55]	validation-rmse:8.55994
# [56]	validation-rmse:8.53835
# [57]	validation-rmse:8.52007
# [58]	validation-rmse:8.50510
# [59]	validation-rmse:8.49227
# [60]	validation-rmse:8.48151
# [61]	validation-rmse:8.47257
# [62]	validation-rmse:8.46414
# [63]	validation-rmse:8.45684
# [64]	validation-rmse:8.45061
# [65]	validation-rmse:8.44543
# [66]	validation-rmse:8.44118
# [67]	validation-rmse:8.43762
# [68]	validation-rmse:8.43486
# [69]	validation-rmse:8.43238
# [70]	validation-rmse:8.43068
# [71]	validation-rmse:8.42924
# [72]	validation-rmse:8.42830
# [73]	validation-rmse:8.42817
# [74]	validation-rmse:8.42807
# [75]	validation-rmse:8.42769
# [76]	validation-rmse:8.42774
# [77]	validation-rmse:8.42757
# [78]	validation-rmse:8.42724
# [79]	validation-rmse:8.42740
# [80]	validation-rmse:8.42700
# [81]	validation-rmse:8.42688
# [82]	validation-rmse:8.42672
# [83]	validation-rmse:8.42648
# [84]	validation-rmse:8.42628
# [85]	validation-rmse:8.42637
# [86]	validation-rmse:8.42645
# [87]	validation-rmse:8.42653
# [88]	validation-rmse:8.42649
# [89]	validation-rmse:8.42644
# [90]	validation-rmse:8.42665
# [91]	validation-rmse:8.42663
# [92]	validation-rmse:8.42666
# [93]	validation-rmse:8.42672
# [94]	validation-rmse:8.42684
# [95]	validation-rmse:8.42683
# [96]	validation-rmse:8.42688
# [97]	validation-rmse:8.42690
# [98]	validation-rmse:8.42691
# [99]	validation-rmse:8.42695
# [100]	validation-rmse:8.42698
# [101]	validation-rmse:8.42698
# [102]	validation-rmse:8.42699
# [103]	validation-rmse:8.42702
# [104]	validation-rmse:8.42700
# [105]	validation-rmse:8.42708
# [106]	validation-rmse:8.42719
# [107]	validation-rmse:8.42726
# [108]	validation-rmse:8.42726
# [109]	validation-rmse:8.42734
# [110]	validation-rmse:8.42735
# [111]	validation-rmse:8.42732
# [112]	validation-rmse:8.42735
# [113]	validation-rmse:8.42736
# [114]	validation-rmse:8.42741
# [115]	validation-rmse:8.42746
# [116]	validation-rmse:8.42757
# [117]	validation-rmse:8.42759
# [118]	validation-rmse:8.42764
# [119]	validation-rmse:8.42769
# [120]	validation-rmse:8.42773
# [121]	validation-rmse:8.42777
# [122]	validation-rmse:8.42782
# [123]	validation-rmse:8.42781
# [124]	validation-rmse:8.42782
# [125]	validation-rmse:8.42783
# [126]	validation-rmse:8.42787
# [127]	validation-rmse:8.42785
# [128]	validation-rmse:8.42790
# [129]	validation-rmse:8.42799
# [130]	validation-rmse:8.42802
# [131]	validation-rmse:8.42808
# [132]	validation-rmse:8.42812
# [133]	validation-rmse:8.42817
# [134]	validation-rmse:8.42823
# [18:18:17] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:136.16525
# [1]	validation-rmse:115.26842
# [2]	validation-rmse:97.58093
# [3]	validation-rmse:82.73841
# [4]	validation-rmse:70.18489
# [5]	validation-rmse:59.55108
# [6]	validation-rmse:50.58546
# [7]	validation-rmse:43.03996
# [8]	validation-rmse:36.71201
# [9]	validation-rmse:31.40407
# [10]	validation-rmse:26.95941
# [11]	validation-rmse:23.16293
# [12]	validation-rmse:20.05922
# [13]	validation-rmse:17.50034
# [14]	validation-rmse:15.44986
# [15]	validation-rmse:13.74641
# [16]	validation-rmse:12.34540
# [17]	validation-rmse:11.27159
# [18]	validation-rmse:10.47451
# [19]	validation-rmse:9.75020
# [20]	validation-rmse:9.30307
# [21]	validation-rmse:8.89637
# [22]	validation-rmse:8.58003
# [23]	validation-rmse:8.31350
# [24]	validation-rmse:8.06910
# [25]	validation-rmse:7.84252
# [26]	validation-rmse:7.93197
# [27]	validation-rmse:8.03739
# [28]	validation-rmse:8.04932
# [29]	validation-rmse:8.02029
# [30]	validation-rmse:8.05012
# [31]	validation-rmse:7.95890
# [32]	validation-rmse:7.96380
# [33]	validation-rmse:7.95189
# [34]	validation-rmse:8.04926
# [35]	validation-rmse:8.14081
# [36]	validation-rmse:8.15715
# [37]	validation-rmse:8.23929
# [38]	validation-rmse:8.19183
# [39]	validation-rmse:8.27245
# [40]	validation-rmse:8.29544
# [41]	validation-rmse:8.35586
# [42]	validation-rmse:8.34454
# [43]	validation-rmse:8.35800
# [44]	validation-rmse:8.35101
# [45]	validation-rmse:8.39810
# [46]	validation-rmse:8.42474
# [47]	validation-rmse:8.42725
# [48]	validation-rmse:8.43147
# [49]	validation-rmse:8.43775
# [50]	validation-rmse:8.49301
# [51]	validation-rmse:8.48868
# [52]	validation-rmse:8.53853
# [53]	validation-rmse:8.52834
# [54]	validation-rmse:8.49397
# [55]	validation-rmse:8.50798
# [56]	validation-rmse:8.50146
# [57]	validation-rmse:8.49557
# [58]	validation-rmse:8.49403
# [59]	validation-rmse:8.51685
# [60]	validation-rmse:8.49448
# [61]	validation-rmse:8.47908
# [62]	validation-rmse:8.48964
# [63]	validation-rmse:8.51656
# [64]	validation-rmse:8.50324
# [65]	validation-rmse:8.51540
# [66]	validation-rmse:8.51689
# [67]	validation-rmse:8.51514
# [68]	validation-rmse:8.50539
# [69]	validation-rmse:8.51359
# [70]	validation-rmse:8.49881
# [71]	validation-rmse:8.49652
# [72]	validation-rmse:8.53210
# [73]	validation-rmse:8.53099
# [74]	validation-rmse:8.53975
# [18:18:18] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:62.37000
# [1]	validation-rmse:24.99804
# [2]	validation-rmse:12.21367
# [3]	validation-rmse:8.85948
# [4]	validation-rmse:8.31431
# [5]	validation-rmse:8.24258
# [6]	validation-rmse:8.20040
# [7]	validation-rmse:8.22794
# [8]	validation-rmse:8.22966
# [9]	validation-rmse:8.22767
# [10]	validation-rmse:8.24171
# [11]	validation-rmse:8.25625
# [12]	validation-rmse:8.25911
# [13]	validation-rmse:8.26359
# [14]	validation-rmse:8.26826
# [15]	validation-rmse:8.27894
# [16]	validation-rmse:8.28038
# [17]	validation-rmse:8.28142
# [18]	validation-rmse:8.28582
# [19]	validation-rmse:8.28483
# [20]	validation-rmse:8.27714
# [21]	validation-rmse:8.27764
# [22]	validation-rmse:8.27478
# [23]	validation-rmse:8.27303
# [24]	validation-rmse:8.27211
# [25]	validation-rmse:8.27476
# [26]	validation-rmse:8.27489
# [27]	validation-rmse:8.27288
# [28]	validation-rmse:8.27175
# [29]	validation-rmse:8.27268
# [30]	validation-rmse:8.27314
# [31]	validation-rmse:8.27176
# [32]	validation-rmse:8.27223
# [33]	validation-rmse:8.27089
# [34]	validation-rmse:8.27040
# [35]	validation-rmse:8.27075
# [36]	validation-rmse:8.27133
# [37]	validation-rmse:8.27135
# [38]	validation-rmse:8.27108
# [39]	validation-rmse:8.27134
# [40]	validation-rmse:8.27173
# [41]	validation-rmse:8.27139
# [42]	validation-rmse:8.27125
# [43]	validation-rmse:8.27108
# [44]	validation-rmse:8.27104
# [45]	validation-rmse:8.27071
# [46]	validation-rmse:8.27068
# [47]	validation-rmse:8.27059
# [48]	validation-rmse:8.27059
# [49]	validation-rmse:8.27058
# [50]	validation-rmse:8.27053
# [51]	validation-rmse:8.27076
# [52]	validation-rmse:8.27061
# [53]	validation-rmse:8.27076
# [54]	validation-rmse:8.27074
# [55]	validation-rmse:8.27069
# [56]	validation-rmse:8.27067
# [18:18:19] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:102.00260
# [1]	validation-rmse:64.85695
# [2]	validation-rmse:41.80329
# [3]	validation-rmse:27.03978
# [4]	validation-rmse:18.04383
# [5]	validation-rmse:12.78002
# [6]	validation-rmse:10.10184
# [7]	validation-rmse:8.85382
# [8]	validation-rmse:8.28180
# [9]	validation-rmse:7.89342
# [10]	validation-rmse:7.79169
# [11]	validation-rmse:7.95173
# [12]	validation-rmse:7.78969
# [13]	validation-rmse:7.80331
# [14]	validation-rmse:7.82195
# [15]	validation-rmse:7.92253
# [16]	validation-rmse:7.99341
# [17]	validation-rmse:8.00378
# [18]	validation-rmse:8.02024
# [19]	validation-rmse:8.02172
# [20]	validation-rmse:8.02166
# [21]	validation-rmse:8.02510
# [22]	validation-rmse:7.94238
# [23]	validation-rmse:7.94825
# [24]	validation-rmse:7.95525
# [25]	validation-rmse:7.99018
# [26]	validation-rmse:8.00146
# [27]	validation-rmse:8.02940
# [28]	validation-rmse:8.05492
# [29]	validation-rmse:8.07584
# [30]	validation-rmse:8.09956
# [31]	validation-rmse:8.05041
# [32]	validation-rmse:8.03691
# [33]	validation-rmse:8.04343
# [34]	validation-rmse:8.01751
# [35]	validation-rmse:8.05119
# [36]	validation-rmse:8.04262
# [37]	validation-rmse:8.06730
# [38]	validation-rmse:8.06535
# [39]	validation-rmse:8.08119
# [40]	validation-rmse:8.08167
# [41]	validation-rmse:8.07335
# [42]	validation-rmse:8.06870
# [43]	validation-rmse:8.06825
# [44]	validation-rmse:8.09251
# [45]	validation-rmse:8.10518
# [46]	validation-rmse:8.09866
# [47]	validation-rmse:8.11052
# [48]	validation-rmse:8.11128
# [49]	validation-rmse:8.12189
# [50]	validation-rmse:8.11421
# [51]	validation-rmse:8.11693
# [52]	validation-rmse:8.10977
# [53]	validation-rmse:8.10489
# [54]	validation-rmse:8.11628
# [55]	validation-rmse:8.11366
# [56]	validation-rmse:8.11595
# [57]	validation-rmse:8.11683
# [58]	validation-rmse:8.11700
# [59]	validation-rmse:8.11114
# [60]	validation-rmse:8.11902
# [61]	validation-rmse:8.11692
# [62]	validation-rmse:8.12558
# [18:18:20] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:62.13595
# [1]	validation-rmse:25.90703
# [2]	validation-rmse:13.83170
# [3]	validation-rmse:9.81663
# [4]	validation-rmse:8.56185
# [5]	validation-rmse:8.45359
# [6]	validation-rmse:8.10495
# [7]	validation-rmse:7.87960
# [8]	validation-rmse:7.57252
# [9]	validation-rmse:7.55376
# [10]	validation-rmse:7.77817
# [11]	validation-rmse:7.67771
# [12]	validation-rmse:7.70400
# [13]	validation-rmse:7.73904
# [14]	validation-rmse:7.76376
# [15]	validation-rmse:7.76343
# [16]	validation-rmse:7.82635
# [17]	validation-rmse:7.88907
# [18]	validation-rmse:7.94882
# [19]	validation-rmse:8.04485
# [20]	validation-rmse:8.04934
# [21]	validation-rmse:8.02909
# [22]	validation-rmse:7.95269
# [23]	validation-rmse:8.02028
# [24]	validation-rmse:8.02993
# [25]	validation-rmse:8.02721
# [26]	validation-rmse:8.01944
# [27]	validation-rmse:8.04568
# [28]	validation-rmse:8.10807
# [29]	validation-rmse:8.00427
# [30]	validation-rmse:8.04738
# [31]	validation-rmse:8.04066
# [32]	validation-rmse:8.14431
# [33]	validation-rmse:8.15992
# [34]	validation-rmse:8.16018
# [35]	validation-rmse:8.12304
# [36]	validation-rmse:8.13697
# [37]	validation-rmse:8.16290
# [38]	validation-rmse:8.18712
# [39]	validation-rmse:8.15215
# [40]	validation-rmse:8.13268
# [41]	validation-rmse:8.19008
# [42]	validation-rmse:8.16433
# [43]	validation-rmse:8.19068
# [44]	validation-rmse:8.18189
# [45]	validation-rmse:8.17157
# [46]	validation-rmse:8.22174
# [47]	validation-rmse:8.24469
# [48]	validation-rmse:8.20848
# [49]	validation-rmse:8.27081
# [50]	validation-rmse:8.30695
# [51]	validation-rmse:8.29840
# [52]	validation-rmse:8.28872
# [53]	validation-rmse:8.31015
# [54]	validation-rmse:8.29283
# [55]	validation-rmse:8.28480
# [56]	validation-rmse:8.30097
# [57]	validation-rmse:8.29169
# [58]	validation-rmse:8.27515
# [59]	validation-rmse:8.34876
# [18:18:21] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:68.97769
# [1]	validation-rmse:31.00392
# [2]	validation-rmse:16.05857
# [3]	validation-rmse:11.06810
# [4]	validation-rmse:9.60517
# [5]	validation-rmse:8.84450
# [6]	validation-rmse:8.37716
# [7]	validation-rmse:8.39051
# [8]	validation-rmse:8.43716
# [9]	validation-rmse:8.46515
# [10]	validation-rmse:8.47001
# [11]	validation-rmse:8.57290
# [12]	validation-rmse:8.50223
# [13]	validation-rmse:8.44171
# [14]	validation-rmse:8.49835
# [15]	validation-rmse:8.55271
# [16]	validation-rmse:8.49493
# [17]	validation-rmse:8.52310
# [18]	validation-rmse:8.44535
# [19]	validation-rmse:8.44844
# [20]	validation-rmse:8.48359
# [21]	validation-rmse:8.36689
# [22]	validation-rmse:8.37271
# [23]	validation-rmse:8.41980
# [24]	validation-rmse:8.48661
# [25]	validation-rmse:8.52450
# [26]	validation-rmse:8.49459
# [27]	validation-rmse:8.52043
# [28]	validation-rmse:8.42893
# [29]	validation-rmse:8.50302
# [30]	validation-rmse:8.52734
# [31]	validation-rmse:8.52854
# [32]	validation-rmse:8.50303
# [33]	validation-rmse:8.52179
# [34]	validation-rmse:8.51336
# [35]	validation-rmse:8.50824
# [36]	validation-rmse:8.48029
# [37]	validation-rmse:8.50030
# [38]	validation-rmse:8.51268
# [39]	validation-rmse:8.52060
# [40]	validation-rmse:8.58256
# [41]	validation-rmse:8.58817
# [42]	validation-rmse:8.59973
# [43]	validation-rmse:8.59956
# [44]	validation-rmse:8.53914
# [45]	validation-rmse:8.56268
# [46]	validation-rmse:8.55846
# [47]	validation-rmse:8.54004
# [48]	validation-rmse:8.53769
# [49]	validation-rmse:8.54622
# [50]	validation-rmse:8.56771
# [51]	validation-rmse:8.58892
# [52]	validation-rmse:8.58130
# [53]	validation-rmse:8.59306
# [54]	validation-rmse:8.58551
# [55]	validation-rmse:8.59267
# [56]	validation-rmse:8.58313
# [57]	validation-rmse:8.59056
# [58]	validation-rmse:8.59502
# [59]	validation-rmse:8.61282
# [60]	validation-rmse:8.60227
# [61]	validation-rmse:8.60452
# [62]	validation-rmse:8.61462
# [63]	validation-rmse:8.60549
# [64]	validation-rmse:8.63210
# [65]	validation-rmse:8.63139
# [66]	validation-rmse:8.64520
# [67]	validation-rmse:8.65081
# [68]	validation-rmse:8.65102
# [69]	validation-rmse:8.65010
# [70]	validation-rmse:8.64851
# [71]	validation-rmse:8.64308
# ...
# [35]	validation-rmse:9.06789
# [36]	validation-rmse:9.06525
# [37]	validation-rmse:9.06652
# [38]	validation-rmse:9.06745
# [39]	validation-rmse:9.06736
# [40]	validation-rmse:9.06415
# [41]	validation-rmse:9.06425
# [42]	validation-rmse:9.06439
# [43]	validation-rmse:9.06464
# [44]	validation-rmse:9.06458
# [45]	validation-rmse:9.06316
# [46]	validation-rmse:9.06378
# [47]	validation-rmse:9.06326
# [48]	validation-rmse:9.06292
# [49]	validation-rmse:9.06166
# [50]	validation-rmse:9.06218
# [51]	validation-rmse:9.06148
# [52]	validation-rmse:9.06111
# [53]	validation-rmse:9.05995
# [54]	validation-rmse:9.06003
# [55]	validation-rmse:9.05978
# [56]	validation-rmse:9.05990
# [57]	validation-rmse:9.05995
# [58]	validation-rmse:9.05943
# [59]	validation-rmse:9.05939
# [60]	validation-rmse:9.05933
# [61]	validation-rmse:9.05925
# [62]	validation-rmse:9.05916
# [63]	validation-rmse:9.05898
# [64]	validation-rmse:9.05887
# [65]	validation-rmse:9.05865
# [66]	validation-rmse:9.05897
# [67]	validation-rmse:9.05906
# [68]	validation-rmse:9.05908
# [69]	validation-rmse:9.05899
# [70]	validation-rmse:9.05912
# [71]	validation-rmse:9.05913
# [72]	validation-rmse:9.05903
# [73]	validation-rmse:9.05904
# [74]	validation-rmse:9.05899
# [75]	validation-rmse:9.05904
# [76]	validation-rmse:9.05906
# [77]	validation-rmse:9.05911
# [78]	validation-rmse:9.05911
# [79]	validation-rmse:9.05911
# [80]	validation-rmse:9.05911
# [81]	validation-rmse:9.05912
# [82]	validation-rmse:9.05917
# [83]	validation-rmse:9.05906
# [84]	validation-rmse:9.05901
# [85]	validation-rmse:9.05905
# [86]	validation-rmse:9.05900
# [87]	validation-rmse:9.05906
# [88]	validation-rmse:9.05906
# [89]	validation-rmse:9.05911
# [90]	validation-rmse:9.05911
# [91]	validation-rmse:9.05908
# [92]	validation-rmse:9.05909
# [93]	validation-rmse:9.05899
# [94]	validation-rmse:9.05892
# [95]	validation-rmse:9.05892
# [96]	validation-rmse:9.05892
# [97]	validation-rmse:9.05892
# [98]	validation-rmse:9.05892
# [99]	validation-rmse:9.05892
# [100]	validation-rmse:9.05892
# [101]	validation-rmse:9.05892
# [102]	validation-rmse:9.05892
# [103]	validation-rmse:9.05892
# [104]	validation-rmse:9.05892
# [105]	validation-rmse:9.05892
# [106]	validation-rmse:9.05892
# [107]	validation-rmse:9.05892
# [108]	validation-rmse:9.05892
# [109]	validation-rmse:9.05892
# [110]	validation-rmse:9.05892
# [111]	validation-rmse:9.05892
# [112]	validation-rmse:9.05892
# [113]	validation-rmse:9.05892
# [114]	validation-rmse:9.05892
# [115]	validation-rmse:9.05892
# [18:20:03] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:142.36108
# [1]	validation-rmse:126.01298
# [2]	validation-rmse:111.60289
# [3]	validation-rmse:98.84191
# [4]	validation-rmse:87.55659
# [5]	validation-rmse:77.57957
# [6]	validation-rmse:68.77166
# [7]	validation-rmse:61.00817
# [8]	validation-rmse:54.18297
# [9]	validation-rmse:48.15524
# [10]	validation-rmse:42.79766
# [11]	validation-rmse:38.08991
# [12]	validation-rmse:33.94232
# [13]	validation-rmse:30.35649
# [14]	validation-rmse:27.18461
# [15]	validation-rmse:24.40248
# [16]	validation-rmse:21.98880
# [17]	validation-rmse:19.90272
# [18]	validation-rmse:18.09275
# [19]	validation-rmse:16.53259
# [20]	validation-rmse:15.19480
# [21]	validation-rmse:14.05789
# [22]	validation-rmse:13.05062
# [23]	validation-rmse:12.20779
# [24]	validation-rmse:11.49044
# [25]	validation-rmse:10.90342
# [26]	validation-rmse:10.40591
# [27]	validation-rmse:10.00347
# [28]	validation-rmse:9.67269
# [29]	validation-rmse:9.40073
# [30]	validation-rmse:9.17696
# [31]	validation-rmse:8.99201
# [32]	validation-rmse:8.84880
# [33]	validation-rmse:8.73100
# [34]	validation-rmse:8.62710
# [35]	validation-rmse:8.55499
# [36]	validation-rmse:8.49372
# [37]	validation-rmse:8.43244
# [38]	validation-rmse:8.37172
# [39]	validation-rmse:8.33566
# [40]	validation-rmse:8.30191
# [41]	validation-rmse:8.26782
# [42]	validation-rmse:8.24099
# [43]	validation-rmse:8.21538
# [44]	validation-rmse:8.19457
# [45]	validation-rmse:8.18439
# [46]	validation-rmse:8.16526
# [47]	validation-rmse:8.15449
# [48]	validation-rmse:8.14475
# [49]	validation-rmse:8.13449
# [50]	validation-rmse:8.12520
# [51]	validation-rmse:8.11608
# [52]	validation-rmse:8.10965
# [53]	validation-rmse:8.10949
# [54]	validation-rmse:8.11863
# [55]	validation-rmse:8.11900
# [56]	validation-rmse:8.10925
# [57]	validation-rmse:8.10938
# [58]	validation-rmse:8.11045
# [59]	validation-rmse:8.10810
# [60]	validation-rmse:8.10557
# [61]	validation-rmse:8.10723
# [62]	validation-rmse:8.11153
# [63]	validation-rmse:8.10974
# [64]	validation-rmse:8.10602
# [65]	validation-rmse:8.10027
# [66]	validation-rmse:8.09755
# [67]	validation-rmse:8.09973
# [68]	validation-rmse:8.09892
# [69]	validation-rmse:8.09889
# [70]	validation-rmse:8.10005
# [71]	validation-rmse:8.10863
# [72]	validation-rmse:8.10758
# [73]	validation-rmse:8.10735
# [74]	validation-rmse:8.10865
# [75]	validation-rmse:8.10574
# [76]	validation-rmse:8.10430
# [77]	validation-rmse:8.10173
# [78]	validation-rmse:8.10198
# [79]	validation-rmse:8.10430
# [80]	validation-rmse:8.10335
# [81]	validation-rmse:8.10420
# [82]	validation-rmse:8.10147
# [83]	validation-rmse:8.10067
# [84]	validation-rmse:8.09984
# [85]	validation-rmse:8.10031
# [86]	validation-rmse:8.10379
# [87]	validation-rmse:8.10290
# [88]	validation-rmse:8.10261
# [89]	validation-rmse:8.10317
# [90]	validation-rmse:8.10275
# [91]	validation-rmse:8.10304
# [92]	validation-rmse:8.10381
# [93]	validation-rmse:8.10677
# [94]	validation-rmse:8.10777
# [95]	validation-rmse:8.10623
# [96]	validation-rmse:8.10767
# [97]	validation-rmse:8.10631
# [98]	validation-rmse:8.10421
# [99]	validation-rmse:8.10387
# [100]	validation-rmse:8.10903
# [101]	validation-rmse:8.10708
# [102]	validation-rmse:8.10688
# [103]	validation-rmse:8.10899
# [104]	validation-rmse:8.10918
# [105]	validation-rmse:8.10920
# [106]	validation-rmse:8.11093
# [107]	validation-rmse:8.11460
# [108]	validation-rmse:8.11446
# [109]	validation-rmse:8.11314
# [110]	validation-rmse:8.11203
# [111]	validation-rmse:8.11231
# [112]	validation-rmse:8.11301
# [113]	validation-rmse:8.11122
# [114]	validation-rmse:8.11236
# [115]	validation-rmse:8.11289
# 100%|██████████| 50/50 [01:52<00:00,  2.25s/trial, best loss: 7.17631533094335]

# %%
 
params = {
    'learning_rate': 0.0502324462543933,
    'max_depth':	75,
    'min_child_weight':	19.592017909776523,
    'objective':	'reg:linear',
    'reg_alpha':	0.36230511158752154,
    'reg_lambda':	0.2713344777035102,
    'seed':	42
}

mlflow.end_run()
with mlflow.start_run():
    mlflow.set_tag("model", "xgboost")
    mlflow.log_params(params)

    booster = xgb.train(
        params=params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(test, 'validation')],
        early_stopping_rounds=50)
    y_pred = booster.predict(test)
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [19:34:19] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:152.85409
# [1]	validation-rmse:145.27360
# [2]	validation-rmse:138.08283
# [3]	validation-rmse:131.25744
# [4]	validation-rmse:124.76020
# [5]	validation-rmse:118.59694
# [6]	validation-rmse:112.74079
# [7]	validation-rmse:107.20838
# [8]	validation-rmse:101.95065
# [9]	validation-rmse:96.94473
# [10]	validation-rmse:92.22210
# [11]	validation-rmse:87.71454
# [12]	validation-rmse:83.44227
# [13]	validation-rmse:79.39034
# [14]	validation-rmse:75.55353
# [15]	validation-rmse:71.91189
# [16]	validation-rmse:68.45362
# [17]	validation-rmse:65.17905
# [18]	validation-rmse:62.06477
# [19]	validation-rmse:59.11363
# [20]	validation-rmse:56.30478
# [21]	validation-rmse:53.67993
# [22]	validation-rmse:51.18163
# [23]	validation-rmse:48.81268
# [24]	validation-rmse:46.58306
# [25]	validation-rmse:44.46794
# [26]	validation-rmse:42.46373
# [27]	validation-rmse:40.57166
# [28]	validation-rmse:38.75952
# [29]	validation-rmse:37.06063
# [30]	validation-rmse:35.46487
# [31]	validation-rmse:33.95620
# [32]	validation-rmse:32.52733
# [33]	validation-rmse:31.17437
# [34]	validation-rmse:29.89189
# [35]	validation-rmse:28.70932
# [36]	validation-rmse:27.56121
# [37]	validation-rmse:26.51694
# [38]	validation-rmse:25.50111
# [39]	validation-rmse:24.59427
# [40]	validation-rmse:23.70653
# [41]	validation-rmse:22.88766
# [42]	validation-rmse:22.10094
# [43]	validation-rmse:21.39021
# [44]	validation-rmse:20.73106
# [45]	validation-rmse:20.12609
# [46]	validation-rmse:19.57745
# [47]	validation-rmse:19.04161
# [48]	validation-rmse:18.55243
# [49]	validation-rmse:18.08569
# [50]	validation-rmse:17.64556
# [51]	validation-rmse:17.24265
# [52]	validation-rmse:16.86595
# [53]	validation-rmse:16.54039
# [54]	validation-rmse:16.21835
# [55]	validation-rmse:15.93280
# [56]	validation-rmse:15.63596
# [57]	validation-rmse:15.28165
# [58]	validation-rmse:14.97325
# [59]	validation-rmse:14.66327
# [60]	validation-rmse:14.39353
# [61]	validation-rmse:14.12003
# [62]	validation-rmse:13.88477
# [63]	validation-rmse:13.65239
# [64]	validation-rmse:13.45150
# [65]	validation-rmse:13.24622
# [66]	validation-rmse:13.07060
# [67]	validation-rmse:12.84938
# [68]	validation-rmse:12.64603
# [69]	validation-rmse:12.50033
# [70]	validation-rmse:12.32184
# [71]	validation-rmse:12.14440
# [72]	validation-rmse:11.98111
# [73]	validation-rmse:11.83037
# [74]	validation-rmse:11.69790
# [75]	validation-rmse:11.57213
# [76]	validation-rmse:11.46601
# [77]	validation-rmse:11.35322
# [78]	validation-rmse:11.25265
# [79]	validation-rmse:11.12823
# [80]	validation-rmse:11.04162
# [81]	validation-rmse:10.94011
# [82]	validation-rmse:10.83428
# [83]	validation-rmse:10.73155
# [84]	validation-rmse:10.64367
# [85]	validation-rmse:10.56941
# [86]	validation-rmse:10.47156
# [87]	validation-rmse:10.38380
# [88]	validation-rmse:10.30117
# [89]	validation-rmse:10.22474
# [90]	validation-rmse:10.17310
# [91]	validation-rmse:10.10564
# [92]	validation-rmse:10.06435
# [93]	validation-rmse:10.01095
# [94]	validation-rmse:9.99597
# [95]	validation-rmse:9.93445
# [96]	validation-rmse:9.92222
# [97]	validation-rmse:9.89185
# [98]	validation-rmse:9.83444
# [99]	validation-rmse:9.82731
# [100]	validation-rmse:9.79886
# [101]	validation-rmse:9.76240
# [102]	validation-rmse:9.72922
# [103]	validation-rmse:9.70065
# [104]	validation-rmse:9.62484
# [105]	validation-rmse:9.59950
# [106]	validation-rmse:9.57349
# [107]	validation-rmse:9.52833
# [108]	validation-rmse:9.50586
# [109]	validation-rmse:9.44103
# [110]	validation-rmse:9.42375
# [111]	validation-rmse:9.38243
# [112]	validation-rmse:9.34569
# [113]	validation-rmse:9.30227
# [114]	validation-rmse:9.29503
# [115]	validation-rmse:9.26002
# [116]	validation-rmse:9.22305
# [117]	validation-rmse:9.21219
# [118]	validation-rmse:9.17382
# [119]	validation-rmse:9.14933
# [120]	validation-rmse:9.12338
# [121]	validation-rmse:9.11173
# [122]	validation-rmse:9.09027
# [123]	validation-rmse:9.04238
# [124]	validation-rmse:9.00768
# [125]	validation-rmse:8.99378
# [126]	validation-rmse:8.98357
# [127]	validation-rmse:8.95653
# [128]	validation-rmse:8.92539
# [129]	validation-rmse:8.89076
# [130]	validation-rmse:8.85424
# [131]	validation-rmse:8.85452
# [132]	validation-rmse:8.83372
# [133]	validation-rmse:8.83797
# [134]	validation-rmse:8.82442
# [135]	validation-rmse:8.80317
# [136]	validation-rmse:8.80760
# [137]	validation-rmse:8.77740
# [138]	validation-rmse:8.73674
# [139]	validation-rmse:8.71077
# [140]	validation-rmse:8.69225
# [141]	validation-rmse:8.66313
# [142]	validation-rmse:8.64436
# [143]	validation-rmse:8.61049
# [144]	validation-rmse:8.61159
# [145]	validation-rmse:8.60357
# [146]	validation-rmse:8.57669
# [147]	validation-rmse:8.57023
# [148]	validation-rmse:8.53859
# [149]	validation-rmse:8.52243
# [150]	validation-rmse:8.50258
# [151]	validation-rmse:8.49534
# [152]	validation-rmse:8.45637
# [153]	validation-rmse:8.44065
# [154]	validation-rmse:8.42676
# [155]	validation-rmse:8.41506
# [156]	validation-rmse:8.41141
# [157]	validation-rmse:8.37038
# [158]	validation-rmse:8.34656
# [159]	validation-rmse:8.33367
# [160]	validation-rmse:8.30296
# [161]	validation-rmse:8.30104
# [162]	validation-rmse:8.27256
# [163]	validation-rmse:8.27035
# [164]	validation-rmse:8.25443
# [165]	validation-rmse:8.25263
# [166]	validation-rmse:8.24406
# [167]	validation-rmse:8.22445
# [168]	validation-rmse:8.21355
# [169]	validation-rmse:8.21001
# [170]	validation-rmse:8.18656
# [171]	validation-rmse:8.17607
# [172]	validation-rmse:8.16927
# [173]	validation-rmse:8.16630
# [174]	validation-rmse:8.14574
# [175]	validation-rmse:8.13496
# [176]	validation-rmse:8.13213
# [177]	validation-rmse:8.12384
# [178]	validation-rmse:8.11464
# [179]	validation-rmse:8.10694
# [180]	validation-rmse:8.08695
# [181]	validation-rmse:8.09108
# [182]	validation-rmse:8.08248
# [183]	validation-rmse:8.07418
# [184]	validation-rmse:8.05679
# [185]	validation-rmse:8.04967
# [186]	validation-rmse:8.04519
# [187]	validation-rmse:8.03770
# [188]	validation-rmse:8.02478
# [189]	validation-rmse:8.00834
# [190]	validation-rmse:7.99617
# [191]	validation-rmse:7.97299
# [192]	validation-rmse:7.95756
# [193]	validation-rmse:7.93811
# [194]	validation-rmse:7.92124
# [195]	validation-rmse:7.91167
# [196]	validation-rmse:7.90548
# [197]	validation-rmse:7.89893
# [198]	validation-rmse:7.88971
# [199]	validation-rmse:7.88720
# [200]	validation-rmse:7.88060
# [201]	validation-rmse:7.87567
# [202]	validation-rmse:7.87291
# [203]	validation-rmse:7.86135
# [204]	validation-rmse:7.84578
# [205]	validation-rmse:7.83711
# [206]	validation-rmse:7.83535
# [207]	validation-rmse:7.82342
# [208]	validation-rmse:7.81177
# [209]	validation-rmse:7.81075
# [210]	validation-rmse:7.80671
# [211]	validation-rmse:7.79709
# [212]	validation-rmse:7.76904
# [213]	validation-rmse:7.76254
# [214]	validation-rmse:7.75470
# [215]	validation-rmse:7.75142
# [216]	validation-rmse:7.74562
# [217]	validation-rmse:7.73330
# [218]	validation-rmse:7.72634
# [219]	validation-rmse:7.72804
# [220]	validation-rmse:7.72023
# [221]	validation-rmse:7.72301
# [222]	validation-rmse:7.71909
# [223]	validation-rmse:7.71665
# [224]	validation-rmse:7.70165
# [225]	validation-rmse:7.69564
# [226]	validation-rmse:7.69360
# [227]	validation-rmse:7.68937
# [228]	validation-rmse:7.68500
# [229]	validation-rmse:7.66627
# [230]	validation-rmse:7.65361
# [231]	validation-rmse:7.65569
# [232]	validation-rmse:7.65020
# [233]	validation-rmse:7.64152
# [234]	validation-rmse:7.63569
# [235]	validation-rmse:7.62628
# [236]	validation-rmse:7.62315
# [237]	validation-rmse:7.62533
# [238]	validation-rmse:7.61882
# [239]	validation-rmse:7.59642
# [240]	validation-rmse:7.59372
# [241]	validation-rmse:7.57521
# [242]	validation-rmse:7.56448
# [243]	validation-rmse:7.55918
# [244]	validation-rmse:7.55664
# [245]	validation-rmse:7.55598
# [246]	validation-rmse:7.55133
# [247]	validation-rmse:7.54966
# [248]	validation-rmse:7.54515
# [249]	validation-rmse:7.54107
# [250]	validation-rmse:7.53907
# [251]	validation-rmse:7.53685
# [252]	validation-rmse:7.53259
# [253]	validation-rmse:7.51846
# [254]	validation-rmse:7.51496
# [255]	validation-rmse:7.50988
# [256]	validation-rmse:7.50345
# [257]	validation-rmse:7.49369
# [258]	validation-rmse:7.49371
# [259]	validation-rmse:7.48468
# [260]	validation-rmse:7.48100
# [261]	validation-rmse:7.47887
# [262]	validation-rmse:7.47509
# [263]	validation-rmse:7.46994
# [264]	validation-rmse:7.46603
# [265]	validation-rmse:7.46240
# [266]	validation-rmse:7.45571
# [267]	validation-rmse:7.44255
# [268]	validation-rmse:7.43903
# [269]	validation-rmse:7.43628
# [270]	validation-rmse:7.43563
# [271]	validation-rmse:7.41139
# [272]	validation-rmse:7.40796
# [273]	validation-rmse:7.39992
# [274]	validation-rmse:7.39556
# [275]	validation-rmse:7.39179
# [276]	validation-rmse:7.38746
# [277]	validation-rmse:7.38392
# [278]	validation-rmse:7.38140
# [279]	validation-rmse:7.37730
# [280]	validation-rmse:7.36864
# [281]	validation-rmse:7.36710
# [282]	validation-rmse:7.35319
# [283]	validation-rmse:7.34969
# [284]	validation-rmse:7.34700
# [285]	validation-rmse:7.35293
# [286]	validation-rmse:7.35077
# [287]	validation-rmse:7.34691
# [288]	validation-rmse:7.34071
# [289]	validation-rmse:7.33887
# [290]	validation-rmse:7.33705
# [291]	validation-rmse:7.33437
# [292]	validation-rmse:7.33141
# [293]	validation-rmse:7.33378
# [294]	validation-rmse:7.33163
# [295]	validation-rmse:7.32959
# [296]	validation-rmse:7.32340
# [297]	validation-rmse:7.32182
# [298]	validation-rmse:7.31149
# [299]	validation-rmse:7.31130
# [300]	validation-rmse:7.31205
# [301]	validation-rmse:7.30663
# [302]	validation-rmse:7.31078
# [303]	validation-rmse:7.30766
# [304]	validation-rmse:7.30878
# [305]	validation-rmse:7.30605
# [306]	validation-rmse:7.30103
# [307]	validation-rmse:7.30080
# [308]	validation-rmse:7.29899
# [309]	validation-rmse:7.30006
# [310]	validation-rmse:7.29982
# [311]	validation-rmse:7.30135
# [312]	validation-rmse:7.29437
# [313]	validation-rmse:7.28980
# [314]	validation-rmse:7.29968
# [315]	validation-rmse:7.30390
# [316]	validation-rmse:7.29947
# [317]	validation-rmse:7.29382
# [318]	validation-rmse:7.29267
# [319]	validation-rmse:7.29045
# [320]	validation-rmse:7.29085
# [321]	validation-rmse:7.28816
# [322]	validation-rmse:7.28223
# [323]	validation-rmse:7.27931
# [324]	validation-rmse:7.27832
# [325]	validation-rmse:7.27657
# [326]	validation-rmse:7.27339
# [327]	validation-rmse:7.27619
# [328]	validation-rmse:7.28044
# [329]	validation-rmse:7.27897
# [330]	validation-rmse:7.28201
# [331]	validation-rmse:7.28283
# [332]	validation-rmse:7.27969
# [333]	validation-rmse:7.27636
# [334]	validation-rmse:7.27515
# [335]	validation-rmse:7.28177
# [336]	validation-rmse:7.28354
# [337]	validation-rmse:7.27880
# [338]	validation-rmse:7.28405
# [339]	validation-rmse:7.27122
# [340]	validation-rmse:7.26494
# [341]	validation-rmse:7.26017
# [342]	validation-rmse:7.26108
# [343]	validation-rmse:7.24712
# [344]	validation-rmse:7.23675
# [345]	validation-rmse:7.23872
# [346]	validation-rmse:7.24239
# [347]	validation-rmse:7.24632
# [348]	validation-rmse:7.24853
# [349]	validation-rmse:7.25272
# [350]	validation-rmse:7.24300
# [351]	validation-rmse:7.23410
# [352]	validation-rmse:7.23120
# [353]	validation-rmse:7.23039
# [354]	validation-rmse:7.23390
# [355]	validation-rmse:7.23117
# [356]	validation-rmse:7.22848
# [357]	validation-rmse:7.22912
# [358]	validation-rmse:7.22752
# [359]	validation-rmse:7.21905
# [360]	validation-rmse:7.21429
# [361]	validation-rmse:7.21811
# [362]	validation-rmse:7.21360
# [363]	validation-rmse:7.21583
# [364]	validation-rmse:7.22060
# [365]	validation-rmse:7.21116
# [366]	validation-rmse:7.20042
# [367]	validation-rmse:7.20441
# [368]	validation-rmse:7.20031
# [369]	validation-rmse:7.19842
# [370]	validation-rmse:7.20240
# [371]	validation-rmse:7.20383
# [372]	validation-rmse:7.19572
# [373]	validation-rmse:7.19902
# [374]	validation-rmse:7.18191
# [375]	validation-rmse:7.18156
# [376]	validation-rmse:7.18566
# [377]	validation-rmse:7.18594
# [378]	validation-rmse:7.18763
# [379]	validation-rmse:7.18569
# [380]	validation-rmse:7.18592
# [381]	validation-rmse:7.18388
# [382]	validation-rmse:7.18743
# [383]	validation-rmse:7.19042
# [384]	validation-rmse:7.19320
# [385]	validation-rmse:7.18267
# [386]	validation-rmse:7.17517
# [387]	validation-rmse:7.17913
# [388]	validation-rmse:7.17375
# [389]	validation-rmse:7.17342
# [390]	validation-rmse:7.17164
# [391]	validation-rmse:7.17122
# [392]	validation-rmse:7.17143
# [393]	validation-rmse:7.17099
# [394]	validation-rmse:7.16455
# [395]	validation-rmse:7.16265
# [396]	validation-rmse:7.16795
# [397]	validation-rmse:7.16674
# [398]	validation-rmse:7.16697
# [399]	validation-rmse:7.16615
# [400]	validation-rmse:7.15724
# [401]	validation-rmse:7.15787
# [402]	validation-rmse:7.15164
# [403]	validation-rmse:7.15373
# [404]	validation-rmse:7.15261
# [405]	validation-rmse:7.15545
# [406]	validation-rmse:7.14921
# [407]	validation-rmse:7.15118
# [408]	validation-rmse:7.14990
# [409]	validation-rmse:7.15187
# [410]	validation-rmse:7.15280
# [411]	validation-rmse:7.15089
# [412]	validation-rmse:7.15020
# [413]	validation-rmse:7.14988
# [414]	validation-rmse:7.15232
# [415]	validation-rmse:7.15444
# [416]	validation-rmse:7.14434
# [417]	validation-rmse:7.14707
# [418]	validation-rmse:7.15026
# [419]	validation-rmse:7.14822
# [420]	validation-rmse:7.14740
# [421]	validation-rmse:7.15313
# [422]	validation-rmse:7.15268
# [423]	validation-rmse:7.15524
# [424]	validation-rmse:7.15843
# [425]	validation-rmse:7.15576
# [426]	validation-rmse:7.15810
# [427]	validation-rmse:7.16381
# [428]	validation-rmse:7.16021
# [429]	validation-rmse:7.15660
# [430]	validation-rmse:7.15542
# [431]	validation-rmse:7.16032
# [432]	validation-rmse:7.15890
# [433]	validation-rmse:7.16408
# [434]	validation-rmse:7.16679
# [435]	validation-rmse:7.16493
# [436]	validation-rmse:7.16544
# [437]	validation-rmse:7.17059
# [438]	validation-rmse:7.17313
# [439]	validation-rmse:7.17331
# [440]	validation-rmse:7.16465
# [441]	validation-rmse:7.16444
# [442]	validation-rmse:7.16286
# [443]	validation-rmse:7.16765
# [444]	validation-rmse:7.15979
# [445]	validation-rmse:7.15958
# [446]	validation-rmse:7.15958
# [447]	validation-rmse:7.16174
# [448]	validation-rmse:7.15821
# [449]	validation-rmse:7.15218
# [450]	validation-rmse:7.15563
# [451]	validation-rmse:7.16001
# [452]	validation-rmse:7.16455
# [453]	validation-rmse:7.16656
# [454]	validation-rmse:7.16198
# [455]	validation-rmse:7.16242
# [456]	validation-rmse:7.16424
# [457]	validation-rmse:7.16195
# [458]	validation-rmse:7.16526
# [459]	validation-rmse:7.16103
# [460]	validation-rmse:7.16391
# [461]	validation-rmse:7.16703
# [462]	validation-rmse:7.17144
# [463]	validation-rmse:7.17016
# [464]	validation-rmse:7.17277
# [465]	validation-rmse:7.17761
# [466]	validation-rmse:7.17632
# 2023/07/21 19:34:25 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.

# %%
# 2 logging artifacts

params = {
    'learning_rate': 0.0502324462543933,
    'max_depth':	75,
    'min_child_weight':	19.592017909776523,
    'objective':	'reg:linear',
    'reg_alpha':	0.36230511158752154,
    'reg_lambda':	0.2713344777035102,
    'seed':	42
}
with mlflow.start_run():
    mlflow.set_tag("model", "xgboost")
    mlflow.log_params(params)

    booster = xgb.train(
        params=params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(test, 'validation')],
        early_stopping_rounds=50)
    y_pred = booster.predict(test)
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(booster, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")
    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [19:48:00] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:152.85409
# [1]	validation-rmse:145.27360
# [2]	validation-rmse:138.08283
# [3]	validation-rmse:131.25744
# [4]	validation-rmse:124.76020
# [5]	validation-rmse:118.59694
# [6]	validation-rmse:112.74079
# [7]	validation-rmse:107.20838
# [8]	validation-rmse:101.95065
# [9]	validation-rmse:96.94473
# [10]	validation-rmse:92.22210
# [11]	validation-rmse:87.71454
# [12]	validation-rmse:83.44227
# [13]	validation-rmse:79.39034
# [14]	validation-rmse:75.55353
# [15]	validation-rmse:71.91189
# [16]	validation-rmse:68.45362
# [17]	validation-rmse:65.17905
# [18]	validation-rmse:62.06477
# [19]	validation-rmse:59.11363
# [20]	validation-rmse:56.30478
# [21]	validation-rmse:53.67993
# [22]	validation-rmse:51.18163
# [23]	validation-rmse:48.81268
# [24]	validation-rmse:46.58306
# [25]	validation-rmse:44.46794
# [26]	validation-rmse:42.46373
# [27]	validation-rmse:40.57166
# [28]	validation-rmse:38.75952
# [29]	validation-rmse:37.06063
# [30]	validation-rmse:35.46487
# [31]	validation-rmse:33.95620
# [32]	validation-rmse:32.52733
# [33]	validation-rmse:31.17437
# [34]	validation-rmse:29.89189
# [35]	validation-rmse:28.70932
# [36]	validation-rmse:27.56121
# [37]	validation-rmse:26.51694
# [38]	validation-rmse:25.50111
# [39]	validation-rmse:24.59427
# [40]	validation-rmse:23.70653
# [41]	validation-rmse:22.88766
# [42]	validation-rmse:22.10094
# [43]	validation-rmse:21.39021
# [44]	validation-rmse:20.73106
# [45]	validation-rmse:20.12609
# [46]	validation-rmse:19.57745
# [47]	validation-rmse:19.04161
# [48]	validation-rmse:18.55243
# [49]	validation-rmse:18.08569
# [50]	validation-rmse:17.64556
# [51]	validation-rmse:17.24265
# [52]	validation-rmse:16.86595
# [53]	validation-rmse:16.54039
# [54]	validation-rmse:16.21835
# [55]	validation-rmse:15.93280
# [56]	validation-rmse:15.63596
# [57]	validation-rmse:15.28165
# [58]	validation-rmse:14.97325
# [59]	validation-rmse:14.66327
# [60]	validation-rmse:14.39353
# [61]	validation-rmse:14.12003
# [62]	validation-rmse:13.88477
# [63]	validation-rmse:13.65239
# [64]	validation-rmse:13.45150
# [65]	validation-rmse:13.24622
# [66]	validation-rmse:13.07060
# [67]	validation-rmse:12.84938
# [68]	validation-rmse:12.64603
# [69]	validation-rmse:12.50033
# [70]	validation-rmse:12.32184
# [71]	validation-rmse:12.14440
# [72]	validation-rmse:11.98111
# [73]	validation-rmse:11.83037
# [74]	validation-rmse:11.69790
# [75]	validation-rmse:11.57213
# [76]	validation-rmse:11.46601
# [77]	validation-rmse:11.35322
# [78]	validation-rmse:11.25265
# [79]	validation-rmse:11.12823
# [80]	validation-rmse:11.04162
# [81]	validation-rmse:10.94011
# [82]	validation-rmse:10.83428
# [83]	validation-rmse:10.73155
# [84]	validation-rmse:10.64367
# [85]	validation-rmse:10.56941
# [86]	validation-rmse:10.47156
# [87]	validation-rmse:10.38380
# [88]	validation-rmse:10.30117
# [89]	validation-rmse:10.22474
# [90]	validation-rmse:10.17310
# [91]	validation-rmse:10.10564
# [92]	validation-rmse:10.06435
# [93]	validation-rmse:10.01095
# [94]	validation-rmse:9.99597
# [95]	validation-rmse:9.93445
# [96]	validation-rmse:9.92222
# [97]	validation-rmse:9.89185
# [98]	validation-rmse:9.83444
# [99]	validation-rmse:9.82731
# [100]	validation-rmse:9.79886
# [101]	validation-rmse:9.76240
# [102]	validation-rmse:9.72922
# [103]	validation-rmse:9.70065
# [104]	validation-rmse:9.62484
# [105]	validation-rmse:9.59950
# [106]	validation-rmse:9.57349
# [107]	validation-rmse:9.52833
# [108]	validation-rmse:9.50586
# [109]	validation-rmse:9.44103
# [110]	validation-rmse:9.42375
# [111]	validation-rmse:9.38243
# [112]	validation-rmse:9.34569
# [113]	validation-rmse:9.30227
# [114]	validation-rmse:9.29503
# [115]	validation-rmse:9.26002
# [116]	validation-rmse:9.22305
# [117]	validation-rmse:9.21219
# [118]	validation-rmse:9.17382
# [119]	validation-rmse:9.14933
# [120]	validation-rmse:9.12338
# [121]	validation-rmse:9.11173
# [122]	validation-rmse:9.09027
# [123]	validation-rmse:9.04238
# [124]	validation-rmse:9.00768
# [125]	validation-rmse:8.99378
# [126]	validation-rmse:8.98357
# [127]	validation-rmse:8.95653
# [128]	validation-rmse:8.92539
# [129]	validation-rmse:8.89076
# [130]	validation-rmse:8.85424
# [131]	validation-rmse:8.85452
# [132]	validation-rmse:8.83372
# [133]	validation-rmse:8.83797
# [134]	validation-rmse:8.82442
# [135]	validation-rmse:8.80317
# [136]	validation-rmse:8.80760
# [137]	validation-rmse:8.77740
# [138]	validation-rmse:8.73674
# [139]	validation-rmse:8.71077
# [140]	validation-rmse:8.69225
# [141]	validation-rmse:8.66313
# [142]	validation-rmse:8.64436
# [143]	validation-rmse:8.61049
# [144]	validation-rmse:8.61159
# [145]	validation-rmse:8.60357
# [146]	validation-rmse:8.57669
# [147]	validation-rmse:8.57023
# [148]	validation-rmse:8.53859
# [149]	validation-rmse:8.52243
# [150]	validation-rmse:8.50258
# [151]	validation-rmse:8.49534
# [152]	validation-rmse:8.45637
# [153]	validation-rmse:8.44065
# [154]	validation-rmse:8.42676
# [155]	validation-rmse:8.41506
# [156]	validation-rmse:8.41141
# [157]	validation-rmse:8.37038
# [158]	validation-rmse:8.34656
# [159]	validation-rmse:8.33367
# [160]	validation-rmse:8.30296
# [161]	validation-rmse:8.30104
# [162]	validation-rmse:8.27256
# [163]	validation-rmse:8.27035
# [164]	validation-rmse:8.25443
# [165]	validation-rmse:8.25263
# [166]	validation-rmse:8.24406
# [167]	validation-rmse:8.22445
# [168]	validation-rmse:8.21355
# [169]	validation-rmse:8.21001
# [170]	validation-rmse:8.18656
# [171]	validation-rmse:8.17607
# [172]	validation-rmse:8.16927
# [173]	validation-rmse:8.16630
# [174]	validation-rmse:8.14574
# [175]	validation-rmse:8.13496
# [176]	validation-rmse:8.13213
# [177]	validation-rmse:8.12384
# [178]	validation-rmse:8.11464
# [179]	validation-rmse:8.10694
# [180]	validation-rmse:8.08695
# [181]	validation-rmse:8.09108
# [182]	validation-rmse:8.08248
# [183]	validation-rmse:8.07418
# [184]	validation-rmse:8.05679
# [185]	validation-rmse:8.04967
# [186]	validation-rmse:8.04519
# [187]	validation-rmse:8.03770
# [188]	validation-rmse:8.02478
# [189]	validation-rmse:8.00834
# [190]	validation-rmse:7.99617
# [191]	validation-rmse:7.97299
# [192]	validation-rmse:7.95756
# [193]	validation-rmse:7.93811
# [194]	validation-rmse:7.92124
# [195]	validation-rmse:7.91167
# [196]	validation-rmse:7.90548
# [197]	validation-rmse:7.89893
# [198]	validation-rmse:7.88971
# [199]	validation-rmse:7.88720
# [200]	validation-rmse:7.88060
# [201]	validation-rmse:7.87567
# [202]	validation-rmse:7.87291
# [203]	validation-rmse:7.86135
# [204]	validation-rmse:7.84578
# [205]	validation-rmse:7.83711
# [206]	validation-rmse:7.83535
# [207]	validation-rmse:7.82342
# [208]	validation-rmse:7.81177
# [209]	validation-rmse:7.81075
# [210]	validation-rmse:7.80671
# [211]	validation-rmse:7.79709
# [212]	validation-rmse:7.76904
# [213]	validation-rmse:7.76254
# [214]	validation-rmse:7.75470
# [215]	validation-rmse:7.75142
# [216]	validation-rmse:7.74562
# [217]	validation-rmse:7.73330
# [218]	validation-rmse:7.72634
# [219]	validation-rmse:7.72804
# [220]	validation-rmse:7.72023
# [221]	validation-rmse:7.72301
# [222]	validation-rmse:7.71909
# [223]	validation-rmse:7.71665
# [224]	validation-rmse:7.70165
# [225]	validation-rmse:7.69564
# [226]	validation-rmse:7.69360
# [227]	validation-rmse:7.68937
# [228]	validation-rmse:7.68500
# [229]	validation-rmse:7.66627
# [230]	validation-rmse:7.65361
# [231]	validation-rmse:7.65569
# [232]	validation-rmse:7.65020
# [233]	validation-rmse:7.64152
# [234]	validation-rmse:7.63569
# [235]	validation-rmse:7.62628
# [236]	validation-rmse:7.62315
# [237]	validation-rmse:7.62533
# [238]	validation-rmse:7.61882
# [239]	validation-rmse:7.59642
# [240]	validation-rmse:7.59372
# [241]	validation-rmse:7.57521
# [242]	validation-rmse:7.56448
# [243]	validation-rmse:7.55918
# [244]	validation-rmse:7.55664
# [245]	validation-rmse:7.55598
# [246]	validation-rmse:7.55133
# [247]	validation-rmse:7.54966
# [248]	validation-rmse:7.54515
# [249]	validation-rmse:7.54107
# [250]	validation-rmse:7.53907
# [251]	validation-rmse:7.53685
# [252]	validation-rmse:7.53259
# [253]	validation-rmse:7.51846
# [254]	validation-rmse:7.51496
# [255]	validation-rmse:7.50988
# [256]	validation-rmse:7.50345
# [257]	validation-rmse:7.49369
# [258]	validation-rmse:7.49371
# [259]	validation-rmse:7.48468
# [260]	validation-rmse:7.48100
# [261]	validation-rmse:7.47887
# [262]	validation-rmse:7.47509
# [263]	validation-rmse:7.46994
# [264]	validation-rmse:7.46603
# [265]	validation-rmse:7.46240
# [266]	validation-rmse:7.45571
# [267]	validation-rmse:7.44255
# [268]	validation-rmse:7.43903
# [269]	validation-rmse:7.43628
# [270]	validation-rmse:7.43563
# [271]	validation-rmse:7.41139
# [272]	validation-rmse:7.40796
# [273]	validation-rmse:7.39992
# [274]	validation-rmse:7.39556
# [275]	validation-rmse:7.39179
# [276]	validation-rmse:7.38746
# [277]	validation-rmse:7.38392
# [278]	validation-rmse:7.38140
# [279]	validation-rmse:7.37730
# [280]	validation-rmse:7.36864
# [281]	validation-rmse:7.36710
# [282]	validation-rmse:7.35319
# [283]	validation-rmse:7.34969
# [284]	validation-rmse:7.34700
# [285]	validation-rmse:7.35293
# [286]	validation-rmse:7.35077
# [287]	validation-rmse:7.34691
# [288]	validation-rmse:7.34071
# [289]	validation-rmse:7.33887
# [290]	validation-rmse:7.33705
# [291]	validation-rmse:7.33437
# [292]	validation-rmse:7.33141
# [293]	validation-rmse:7.33378
# [294]	validation-rmse:7.33163
# [295]	validation-rmse:7.32959
# [296]	validation-rmse:7.32340
# [297]	validation-rmse:7.32182
# [298]	validation-rmse:7.31149
# [299]	validation-rmse:7.31130
# [300]	validation-rmse:7.31205
# [301]	validation-rmse:7.30663
# [302]	validation-rmse:7.31078
# [303]	validation-rmse:7.30766
# [304]	validation-rmse:7.30878
# [305]	validation-rmse:7.30605
# [306]	validation-rmse:7.30103
# [307]	validation-rmse:7.30080
# [308]	validation-rmse:7.29899
# [309]	validation-rmse:7.30006
# [310]	validation-rmse:7.29982
# [311]	validation-rmse:7.30135
# [312]	validation-rmse:7.29437
# [313]	validation-rmse:7.28980
# [314]	validation-rmse:7.29968
# [315]	validation-rmse:7.30390
# [316]	validation-rmse:7.29947
# [317]	validation-rmse:7.29382
# [318]	validation-rmse:7.29267
# [319]	validation-rmse:7.29045
# [320]	validation-rmse:7.29085
# [321]	validation-rmse:7.28816
# [322]	validation-rmse:7.28223
# [323]	validation-rmse:7.27931
# [324]	validation-rmse:7.27832
# [325]	validation-rmse:7.27657
# [326]	validation-rmse:7.27339
# [327]	validation-rmse:7.27619
# [328]	validation-rmse:7.28044
# [329]	validation-rmse:7.27897
# [330]	validation-rmse:7.28201
# [331]	validation-rmse:7.28283
# [332]	validation-rmse:7.27969
# [333]	validation-rmse:7.27636
# [334]	validation-rmse:7.27515
# [335]	validation-rmse:7.28177
# [336]	validation-rmse:7.28354
# [337]	validation-rmse:7.27880
# [338]	validation-rmse:7.28405
# [339]	validation-rmse:7.27122
# [340]	validation-rmse:7.26494
# [341]	validation-rmse:7.26017
# [342]	validation-rmse:7.26108
# [343]	validation-rmse:7.24712
# [344]	validation-rmse:7.23675
# [345]	validation-rmse:7.23872
# [346]	validation-rmse:7.24239
# [347]	validation-rmse:7.24632
# [348]	validation-rmse:7.24853
# [349]	validation-rmse:7.25272
# [350]	validation-rmse:7.24300
# [351]	validation-rmse:7.23410
# [352]	validation-rmse:7.23120
# [353]	validation-rmse:7.23039
# [354]	validation-rmse:7.23390
# [355]	validation-rmse:7.23117
# [356]	validation-rmse:7.22848
# [357]	validation-rmse:7.22912
# [358]	validation-rmse:7.22752
# [359]	validation-rmse:7.21905
# [360]	validation-rmse:7.21429
# [361]	validation-rmse:7.21811
# [362]	validation-rmse:7.21360
# [363]	validation-rmse:7.21583
# [364]	validation-rmse:7.22060
# [365]	validation-rmse:7.21116
# [366]	validation-rmse:7.20042
# [367]	validation-rmse:7.20441
# [368]	validation-rmse:7.20031
# [369]	validation-rmse:7.19842
# [370]	validation-rmse:7.20240
# [371]	validation-rmse:7.20383
# [372]	validation-rmse:7.19572
# [373]	validation-rmse:7.19902
# [374]	validation-rmse:7.18191
# [375]	validation-rmse:7.18156
# [376]	validation-rmse:7.18566
# [377]	validation-rmse:7.18594
# [378]	validation-rmse:7.18763
# [379]	validation-rmse:7.18569
# [380]	validation-rmse:7.18592
# [381]	validation-rmse:7.18388
# [382]	validation-rmse:7.18743
# [383]	validation-rmse:7.19042
# [384]	validation-rmse:7.19320
# [385]	validation-rmse:7.18267
# [386]	validation-rmse:7.17517
# [387]	validation-rmse:7.17913
# [388]	validation-rmse:7.17375
# [389]	validation-rmse:7.17342
# [390]	validation-rmse:7.17164
# [391]	validation-rmse:7.17122
# [392]	validation-rmse:7.17143
# [393]	validation-rmse:7.17099
# [394]	validation-rmse:7.16455
# [395]	validation-rmse:7.16265
# [396]	validation-rmse:7.16795
# [397]	validation-rmse:7.16674
# [398]	validation-rmse:7.16697
# [399]	validation-rmse:7.16615
# [400]	validation-rmse:7.15724
# [401]	validation-rmse:7.15787
# [402]	validation-rmse:7.15164
# [403]	validation-rmse:7.15373
# [404]	validation-rmse:7.15261
# [405]	validation-rmse:7.15545
# [406]	validation-rmse:7.14921
# [407]	validation-rmse:7.15118
# [408]	validation-rmse:7.14990
# [409]	validation-rmse:7.15187
# [410]	validation-rmse:7.15280
# [411]	validation-rmse:7.15089
# [412]	validation-rmse:7.15020
# [413]	validation-rmse:7.14988
# [414]	validation-rmse:7.15232
# [415]	validation-rmse:7.15444
# [416]	validation-rmse:7.14434
# [417]	validation-rmse:7.14707
# [418]	validation-rmse:7.15026
# [419]	validation-rmse:7.14822
# [420]	validation-rmse:7.14740
# [421]	validation-rmse:7.15313
# [422]	validation-rmse:7.15268
# [423]	validation-rmse:7.15524
# [424]	validation-rmse:7.15843
# [425]	validation-rmse:7.15576
# [426]	validation-rmse:7.15810
# [427]	validation-rmse:7.16381
# [428]	validation-rmse:7.16021
# [429]	validation-rmse:7.15660
# [430]	validation-rmse:7.15542
# [431]	validation-rmse:7.16032
# [432]	validation-rmse:7.15890
# [433]	validation-rmse:7.16408
# [434]	validation-rmse:7.16679
# [435]	validation-rmse:7.16493
# [436]	validation-rmse:7.16544
# [437]	validation-rmse:7.17059
# [438]	validation-rmse:7.17313
# [439]	validation-rmse:7.17331
# [440]	validation-rmse:7.16465
# [441]	validation-rmse:7.16444
# [442]	validation-rmse:7.16286
# [443]	validation-rmse:7.16765
# [444]	validation-rmse:7.15979
# [445]	validation-rmse:7.15958
# [446]	validation-rmse:7.15958
# [447]	validation-rmse:7.16174
# [448]	validation-rmse:7.15821
# [449]	validation-rmse:7.15218
# [450]	validation-rmse:7.15563
# [451]	validation-rmse:7.16001
# [452]	validation-rmse:7.16455
# [453]	validation-rmse:7.16656
# [454]	validation-rmse:7.16198
# [455]	validation-rmse:7.16242
# [456]	validation-rmse:7.16424
# [457]	validation-rmse:7.16195
# [458]	validation-rmse:7.16526
# [459]	validation-rmse:7.16103
# [460]	validation-rmse:7.16391
# [461]	validation-rmse:7.16703
# [462]	validation-rmse:7.17144
# [463]	validation-rmse:7.17016
# [464]	validation-rmse:7.17277
# [465]	validation-rmse:7.17761
# [466]	validation-rmse:7.17632
# 2023/07/21 19:48:05 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.

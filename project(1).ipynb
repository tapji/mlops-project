# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd
import polars as pl
import pickle
from sklearn.impute import SimpleImputer

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# for regression models
from sklearn.feature_extraction import DictVectorizer
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

# for classification models
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, StackingClassifier
from xgboost import XGBClassifier

#performance
from sklearn.metrics import mean_squared_error

# To supress warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Importing Google colab and drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Importing dataset

# %%
# training dataset

df = pd.read_csv('/content/drive/MyDrive/MLOPs/emission_data.csv', encoding='iso-8859-1')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4625 entries, 0 to 4624
# Data columns (total 45 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Manufacturer                           4625 non-null   object
#  1   Model                                  4625 non-null   object
#  2   Description                            4625 non-null   object
#  3   Transmission                           4386 non-null   object
#  4   Engine Capacity                        4625 non-null   int64
#  5   Fuel Type                              4625 non-null   object
#  6   Powertrain                             4625 non-null   object
#  7   Engine Power (Kw)                      4536 non-null   float64
#  8   Engine Power (PS)                      4404 non-null   float64
#  9   Testing Scheme                         4625 non-null   object
#  10  Euro Standard                          4625 non-null   object
#  11  Diesel VED Supplement                  4625 non-null   bool
#  12  Electric energy consumption Miles/kWh  1433 non-null   float64
#  13  wh/km                                  395 non-null    float64
#  14  Maximum range (Km)                     807 non-null    float64
#  15  Maximum range (Miles)                  272 non-null    float64
#  16  WLTP Imperial Low                      4619 non-null   float64
#  17  WLTP Imperial Medium                   4620 non-null   float64
#  18  WLTP Imperial High                     4620 non-null   float64
#  19  WLTP Imperial Extra High               4620 non-null   float64
#  20  WLTP Imperial Combined                 4620 non-null   float64
#  21  WLTP Imperial Combined (Weighted)      3623 non-null   float64
#  22  WLTP Metric Low                        4620 non-null   float64
#  23  WLTP Metric Medium                     4620 non-null   float64
#  24  WLTP Metric High                       4620 non-null   float64
#  25  WLTP Metric Extra High                 4619 non-null   float64
#  26  WLTP Metric Combined                   4610 non-null   float64
#  27  WLTP Metric Combined (Weighted)        3625 non-null   float64
#  28  WLTP CO2                               4623 non-null   float64
#  29  WLTP CO2 Weighted                      3416 non-null   float64
#  30  Equivalent All Electric Range Miles    403 non-null    float64
#  31  Equivalent All Electric Range KM       634 non-null    float64
#  32  Electric Range City Miles              272 non-null    float64
#  33  Electric Range City Km                 826 non-null    float64
#  34  Annual fuel Cost 10000 Miles           4625 non-null   object
#  35  Annual Electricity cost / 10000 miles  4625 non-null   object
#  36  Total cost / 10000 miles               4625 non-null   object
#  37  Noise Level dB(A)                      4625 non-null   float64
#  38  Emissions CO [mg/km]                   4517 non-null   float64
#  39  THC Emissions [mg/km]                  3667 non-null   float64
#  40  Emissions NOx [mg/km]                  4485 non-null   float64
#  41  THC + NOx Emissions [mg/km]            1602 non-null   float64
#  42  Particulates [No.] [mg/km]             1682 non-null   float64
#  43  RDE NOx Urban                          2461 non-null   float64
#  44  RDE NOx Combined                       2691 non-null   float64
# dtypes: bool(1), float64(32), int64(1), object(11)
# memory usage: 1.6+ MB

# %%
# Observing the correlation between numerical variables using heatmap

plt.figure(figsize=(30,15))
sns.heatmap(df.corr(),annot=True,cmap='Spectral',vmin=-1,vmax=1)
plt.show()

# %%
df.isnull().sum()
# Out:
# Manufacturer                                0
# Model                                       0
# Description                                 0
# Transmission                              239
# Engine Capacity                             0
# Fuel Type                                   0
# Powertrain                                  0
# Engine Power (Kw)                          89
# Engine Power (PS)                         221
# Testing Scheme                              0
# Euro Standard                               0
# Diesel VED Supplement                       0
# Electric energy consumption Miles/kWh    3192
# wh/km                                    4230
# Maximum range (Km)                       3818
# Maximum range (Miles)                    4353
# WLTP Imperial Low                           6
# WLTP Imperial Medium                        5
# WLTP Imperial High                          5
# WLTP Imperial Extra High                    5
# WLTP Imperial Combined                      5
# WLTP Imperial Combined (Weighted)        1002
# WLTP Metric Low                             5
# WLTP Metric Medium                          5
# WLTP Metric High                            5
# WLTP Metric Extra High                      6
# WLTP Metric Combined                       15
# WLTP Metric Combined (Weighted)          1000
# WLTP CO2                                    2
# WLTP CO2 Weighted                        1209
# Equivalent All Electric Range Miles      4222
# Equivalent All Electric Range KM         3991
# Electric Range City Miles                4353
# Electric Range City Km                   3799
# Annual fuel Cost 10000 Miles                0
# Annual Electricity cost / 10000 miles       0
# Total cost / 10000 miles                    0
# Noise Level dB(A)                           0
# Emissions CO [mg/km]                      108
# THC Emissions [mg/km]                     958
# Emissions NOx [mg/km]                     140
# THC + NOx Emissions [mg/km]              3023
# Particulates [No.] [mg/km]               2943
# RDE NOx Urban                            2164
# RDE NOx Combined                         1934
# dtype: int64

# %%
# Remove '£' and ',' sign from 'Total Cost/ 10000 miles' column and convert to numeric values

df['Annual fuel Cost 10000 Miles'] = df['Annual fuel Cost 10000 Miles'].str.replace('£', '')
df['Annual fuel Cost 10000 Miles'] = df['Annual fuel Cost 10000 Miles'].str.replace(',', '').astype(int)

# %%
df['Annual Electricity cost / 10000 miles'] = df['Annual Electricity cost / 10000 miles'].str.replace('£', '')
df['Annual Electricity cost / 10000 miles'] = df['Annual Electricity cost / 10000 miles'].str.replace(',', '').astype(int)

# %%
df['Total cost / 10000 miles'] = df['Total cost / 10000 miles'].str.replace('£', '')
df['Total cost / 10000 miles'] = df['Total cost / 10000 miles'].str.replace(',', '').astype(int)
df.head(10)
# Out:
#   Manufacturer Model                                   Description  \
# 0       ABARTH   595                   595 1.4 145 BHP Convertible
# 1       ABARTH   595                   595 1.4 145 BHP Convertible
# 2       ABARTH   595                     595 1.4 145 BHP Hatchback
# 3       ABARTH   595                     595 1.4 145 BHP Hatchback
# 4       ABARTH   595                           595 1.4 TJET 145bhp
# 5       ABARTH   595                           595 1.4 TJET 145bhp
# 6       ABARTH   595              595 COMPETIZIONE 1.4 TJET 180bhp
# 7       ABARTH   595              595 COMPETIZIONE 1.4 TJET 180bhp
# 8       ABARTH   595              595 COMPETIZIONE 1.4 TJET 180bhp
# 9       ABARTH   595  595 COMPETIZIONE 1.4 TJET 180bhp Convertible
#
#   Transmission  Engine Capacity Fuel Type                        Powertrain  \
# 0           M5             1368    Petrol  Internal Combustion Engine (ICE)
# 1           M5             1368    Petrol  Internal Combustion Engine (ICE)
# 2           M5             1368    Petrol  Internal Combustion Engine (ICE)
# 3           M5             1368    Petrol  Internal Combustion Engine (ICE)
# 4           M5             1368    Petrol  Internal Combustion Engine (ICE)
# 5           M5             1368    Petrol  Internal Combustion Engine (ICE)
# 6           M5             1368    Petrol  Internal Combustion Engine (ICE)
# 7          SA5             1368    Petrol  Internal Combustion Engine (ICE)
# 8          SA5             1368    Petrol  Internal Combustion Engine (ICE)
# 9           M5             1368    Petrol  Internal Combustion Engine (ICE)
#
#    Engine Power (Kw)  Engine Power (PS) Testing Scheme  ...  \
# 0              107.0              145.0           WLTP  ...
# 1              107.0              145.0           WLTP  ...
# 2              107.0              145.0           WLTP  ...
# 3              107.0              145.0           WLTP  ...
# 4              107.0                NaN           WLTP  ...
# 5              107.0                NaN           WLTP  ...
# 6              132.0                NaN           WLTP  ...
# 7              132.0                NaN           WLTP  ...
# 8              132.0                NaN           WLTP  ...
# 9              132.0                NaN           WLTP  ...
#
#   Annual Electricity cost / 10000 miles  Total cost / 10000 miles  \
# 0                                     0                      1935
# 1                                     0                      2043
# 2                                     0                      1935
# 3                                     0                      2043
# 4                                     0                      1828
# 5                                     0                      1908
# 6                                     0                      1854
# 7                                     0                      1881
# 8                                     0                      1962
# 9                                     0                      1854
#
#    Noise Level dB(A)  Emissions CO [mg/km]  THC Emissions [mg/km]  \
# 0               73.5                 760.0                   52.0
# 1               73.5                 760.0                   52.0
# 2               73.5                 760.0                   52.0
# 3               73.5                 760.0                   52.0
# 4               74.0                 829.0                   39.0
# 5               74.0                 829.0                   39.0
# 6               72.0                 561.0                   35.0
# 7               74.0                 493.0                   26.0
# 8               74.0                 493.0                   26.0
# 9               72.0                 561.0                   35.0
#
#    Emissions NOx [mg/km]  THC + NOx Emissions [mg/km]  \
# 0                   27.0                          NaN
# 1                   27.0                          NaN
# 2                   27.0                          NaN
# 3                   27.0                          NaN
# 4                   20.0                          NaN
# 5                   20.0                          NaN
# 6                   18.0                          NaN
# 7                   18.0                          NaN
# 8                   18.0                          NaN
# 9                   18.0                          NaN
#
#    Particulates [No.] [mg/km]  RDE NOx Urban  RDE NOx Combined
# 0                         NaN            NaN               NaN
# 1                         NaN            NaN               NaN
# 2                         NaN            NaN               NaN
# 3                         NaN            NaN               NaN
# 4                         NaN            NaN               NaN
# 5                         NaN            NaN               NaN
# 6                         NaN            NaN               NaN
# 7                         NaN            NaN               NaN
# 8                         NaN            NaN               NaN
# 9                         NaN            NaN               NaN
#
# [10 rows x 45 columns]

# %%
# Verify the column names
print(df.columns)
# Out:
# Index(['Manufacturer', 'Model', 'Description', 'Transmission',
#        'Engine Capacity', 'Fuel Type', 'Powertrain', 'Engine Power (Kw)',
#        'Engine Power (PS)', 'Testing Scheme', 'Euro Standard',
#        'Diesel VED Supplement', 'Electric energy consumption Miles/kWh',
#        'wh/km', 'Maximum range (Km)', 'Maximum range (Miles)',
#        'WLTP Imperial Low', 'WLTP Imperial Medium', 'WLTP Imperial High',
#        'WLTP Imperial Extra High', 'WLTP Imperial Combined',
#        'WLTP Imperial Combined (Weighted)', 'WLTP Metric Low',
#        'WLTP Metric Medium', 'WLTP Metric High', 'WLTP Metric Extra High',
#        'WLTP Metric Combined', 'WLTP Metric Combined (Weighted)', 'WLTP CO2',
#        'WLTP CO2 Weighted', 'Equivalent All Electric Range Miles',
#        'Equivalent All Electric Range KM', 'Electric Range City Miles',
#        'Electric Range City Km', 'Annual fuel Cost 10000 Miles',
#        'Annual Electricity cost / 10000 miles', 'Total cost / 10000 miles',
#        'Noise Level dB(A)', 'Emissions CO [mg/km]', 'THC Emissions [mg/km]',
#        'Emissions NOx [mg/km]', 'THC + NOx Emissions [mg/km]',
#        'Particulates [No.] [mg/km]', 'RDE NOx Urban', 'RDE NOx Combined'],
#       dtype='object')

# %%
# Dropping columns with little or no correlation to emmission values

data = df.drop(['Manufacturer', 'Model', 'Description','Transmission', 'Engine Power (Kw)', 'Engine Power (PS)',
       'Electric energy consumption Miles/kWh', 'wh/km', 'Diesel VED Supplement', 'Testing Scheme', 'Euro Standard', 'Maximum range (Miles)',
       'WLTP Imperial Low', 'WLTP Imperial Medium', 'WLTP Imperial High','WLTP Imperial Extra High', 'WLTP Imperial Combined',
       'WLTP Imperial Combined (Weighted)', 'WLTP Metric Low','WLTP Metric Medium', 'WLTP Metric High', 'WLTP Metric Extra High',
       'WLTP Metric Combined', 'WLTP Metric Combined (Weighted)','WLTP CO2 Weighted', 'Equivalent All Electric Range Miles', 'Electric Range City Miles', 'RDE NOx Urban',], axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4625 entries, 0 to 4624
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Engine Capacity                        4625 non-null   int64
#  1   Fuel Type                              4625 non-null   object
#  2   Powertrain                             4625 non-null   object
#  3   Maximum range (Km)                     807 non-null    float64
#  4   WLTP CO2                               4623 non-null   float64
#  5   Equivalent All Electric Range KM       634 non-null    float64
#  6   Electric Range City Km                 826 non-null    float64
#  7   Annual fuel Cost 10000 Miles           4625 non-null   int64
#  8   Annual Electricity cost / 10000 miles  4625 non-null   int64
#  9   Total cost / 10000 miles               4625 non-null   int64
#  10  Noise Level dB(A)                      4625 non-null   float64
#  11  Emissions CO [mg/km]                   4517 non-null   float64
#  12  THC Emissions [mg/km]                  3667 non-null   float64
#  13  Emissions NOx [mg/km]                  4485 non-null   float64
#  14  THC + NOx Emissions [mg/km]            1602 non-null   float64
#  15  Particulates [No.] [mg/km]             1682 non-null   float64
#  16  RDE NOx Combined                       2691 non-null   float64
# dtypes: float64(11), int64(4), object(2)
# memory usage: 614.4+ KB

# %%
data.isnull().sum()
# Out:
# Engine Capacity                             0
# Fuel Type                                   0
# Powertrain                                  0
# Maximum range (Km)                       3818
# WLTP CO2                                    2
# Equivalent All Electric Range KM         3991
# Electric Range City Km                   3799
# Annual fuel Cost 10000 Miles                0
# Annual Electricity cost / 10000 miles       0
# Total cost / 10000 miles                    0
# Noise Level dB(A)                           0
# Emissions CO [mg/km]                      108
# THC Emissions [mg/km]                     958
# Emissions NOx [mg/km]                     140
# THC + NOx Emissions [mg/km]              3023
# Particulates [No.] [mg/km]               2943
# RDE NOx Combined                         1934
# dtype: int64

# %%
# Verify the column names
print(data.columns)
# Out:
# Index(['Engine Capacity', 'Fuel Type', 'Powertrain', 'Maximum range (Km)',
#        'WLTP CO2', 'Equivalent All Electric Range KM',
#        'Electric Range City Miles', 'Electric Range City Km',
#        'Annual fuel Cost 10000 Miles', 'Annual Electricity cost / 10000 miles',
#        'Total cost / 10000 miles', 'Noise Level dB(A)', 'Emissions CO [mg/km]',
#        'THC Emissions [mg/km]', 'Emissions NOx [mg/km]',
#        'THC + NOx Emissions [mg/km]', 'Particulates [No.] [mg/km]',
#        'RDE NOx Combined'],
#       dtype='object')

# %%
columns_to_impute = ['Maximum range (Km)', 'WLTP CO2','Equivalent All Electric Range KM',
       'Electric Range City Km', 'Emissions CO [mg/km]', 'THC Emissions [mg/km]',
       'Emissions NOx [mg/km]', 'THC + NOx Emissions [mg/km]',
       'Particulates [No.] [mg/km]','RDE NOx Combined']

imputer = SimpleImputer(strategy='mean')

# Impute the missing values in the specified columns
data[columns_to_impute] = imputer.fit_transform(df[columns_to_impute])
data.isnull().sum()
# Out:
# Engine Capacity                          0
# Fuel Type                                0
# Powertrain                               0
# Maximum range (Km)                       0
# WLTP CO2                                 0
# Equivalent All Electric Range KM         0
# Electric Range City Km                   0
# Annual fuel Cost 10000 Miles             0
# Annual Electricity cost / 10000 miles    0
# Total cost / 10000 miles                 0
# Noise Level dB(A)                        0
# Emissions CO [mg/km]                     0
# THC Emissions [mg/km]                    0
# Emissions NOx [mg/km]                    0
# THC + NOx Emissions [mg/km]              0
# Particulates [No.] [mg/km]               0
# RDE NOx Combined                         0
# dtype: int64

# %% [markdown]
# ### Data Pre- Processing

# %%
# Observing the summary statistics of the EasyVisadataset (Numerical variables)

round(data.describe(),2).T
# Out:
#                                         count     mean     std    min  \
# Engine Capacity                        4625.0  1706.91  916.61    0.0
# Maximum range (Km)                     4625.0   123.90   77.12    0.0
# WLTP CO2                               4625.0   149.14   61.17    0.0
# Equivalent All Electric Range KM       4625.0    15.61   11.72    0.0
# Electric Range City Km                 4625.0   159.91  101.75    0.0
# Annual fuel Cost 10000 Miles           4625.0  1721.32  711.43    0.0
# Annual Electricity cost / 10000 miles  4625.0    67.03  233.81    0.0
# Total cost / 10000 miles               4625.0  1788.35  598.87  586.0
# Noise Level dB(A)                      4625.0    65.14   15.32    0.0
# Emissions CO [mg/km]                   4625.0   232.69  200.53    0.0
# THC Emissions [mg/km]                  4625.0    19.64   11.71    0.0
# Emissions NOx [mg/km]                  4625.0    22.04   15.85    0.0
# THC + NOx Emissions [mg/km]            4625.0    38.55   15.99    0.0
# Particulates [No.] [mg/km]             4625.0     0.67    0.46    0.0
# RDE NOx Combined                       4625.0    89.40   30.37    0.0
#
#                                            25%      50%      75%      max
# Engine Capacity                        1199.00  1499.00  1997.00  6749.00
# Maximum range (Km)                      123.90   123.90   123.90   779.00
# WLTP CO2                                126.00   144.00   173.00   380.00
# Equivalent All Electric Range KM         15.61    15.61    15.61   208.00
# Electric Range City Km                  159.91   159.91   159.91   828.00
# Annual fuel Cost 10000 Miles           1424.00  1666.00  1989.00  4488.00
# Annual Electricity cost / 10000 miles     0.00     0.00     0.00  1748.00
# Total cost / 10000 miles               1424.00  1680.00  1999.00  4488.00
# Noise Level dB(A)                        67.00    68.00    69.00    89.20
# Emissions CO [mg/km]                     71.00   187.00   329.00   942.00
# THC Emissions [mg/km]                    13.00    19.64    24.00   118.00
# Emissions NOx [mg/km]                     9.00    21.00    30.00   216.00
# THC + NOx Emissions [mg/km]              38.55    38.55    38.55   129.00
# Particulates [No.] [mg/km]                0.67     0.67     0.67     5.96
# RDE NOx Combined                         60.00    89.40    89.40   187.00

# %%
# Observing the correlation between numerical variables using heatmap

plt.figure(figsize=(20,10))
sns.heatmap(data.corr(),annot=True,cmap='Spectral',vmin=-1,vmax=1)
plt.show()

# %% [markdown]
# #### Observations

# %%
# Converting object datatype to categorical

for feature in data.columns: # Loop through all columns in the dataframe
    if data[feature].dtype == 'object': # Only apply for columns with categorical strings
        data[feature] = pd.Categorical(data[feature])# Replace strings with an integer
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4625 entries, 0 to 4624
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Engine Capacity                        4625 non-null   int64
#  1   Fuel Type                              4625 non-null   category
#  2   Powertrain                             4625 non-null   category
#  3   Maximum range (Km)                     4625 non-null   float64
#  4   WLTP CO2                               4625 non-null   float64
#  5   Equivalent All Electric Range KM       4625 non-null   float64
#  6   Electric Range City Km                 4625 non-null   float64
#  7   Annual fuel Cost 10000 Miles           4625 non-null   int64
#  8   Annual Electricity cost / 10000 miles  4625 non-null   int64
#  9   Total cost / 10000 miles               4625 non-null   int64
#  10  Noise Level dB(A)                      4625 non-null   float64
#  11  Emissions CO [mg/km]                   4625 non-null   float64
#  12  THC Emissions [mg/km]                  4625 non-null   float64
#  13  Emissions NOx [mg/km]                  4625 non-null   float64
#  14  THC + NOx Emissions [mg/km]            4625 non-null   float64
#  15  Particulates [No.] [mg/km]             4625 non-null   float64
#  16  RDE NOx Combined                       4625 non-null   float64
# dtypes: category(2), float64(11), int64(4)
# memory usage: 551.7 KB

# %%
data.head()
# Out:
#    Engine Capacity Fuel Type                        Powertrain  \
# 0             1368    Petrol  Internal Combustion Engine (ICE)
# 1             1368    Petrol  Internal Combustion Engine (ICE)
# 2             1368    Petrol  Internal Combustion Engine (ICE)
# 3             1368    Petrol  Internal Combustion Engine (ICE)
# 4             1368    Petrol  Internal Combustion Engine (ICE)
#
#    Maximum range (Km)  WLTP CO2  Equivalent All Electric Range KM  \
# 0          123.902107     162.0                         15.607256
# 1          123.902107     169.0                         15.607256
# 2          123.902107     162.0                         15.607256
# 3          123.902107     169.0                         15.607256
# 4          123.902107     153.0                         15.607256
#
#    Electric Range City Km  Annual fuel Cost 10000 Miles  \
# 0              159.909201                          1935
# 1              159.909201                          2043
# 2              159.909201                          1935
# 3              159.909201                          2043
# 4              159.909201                          1828
#
#    Annual Electricity cost / 10000 miles  Total cost / 10000 miles  \
# 0                                      0                      1935
# 1                                      0                      2043
# 2                                      0                      1935
# 3                                      0                      2043
# 4                                      0                      1828
#
#    Noise Level dB(A)  Emissions CO [mg/km]  THC Emissions [mg/km]  \
# 0               73.5                 760.0                   52.0
# 1               73.5                 760.0                   52.0
# 2               73.5                 760.0                   52.0
# 3               73.5                 760.0                   52.0
# 4               74.0                 829.0                   39.0
#
#    Emissions NOx [mg/km]  THC + NOx Emissions [mg/km]  \
# 0                   27.0                    38.554931
# 1                   27.0                    38.554931
# 2                   27.0                    38.554931
# 3                   27.0                    38.554931
# 4                   20.0                    38.554931
#
#    Particulates [No.] [mg/km]  RDE NOx Combined
# 0                    0.669727         89.403196
# 1                    0.669727         89.403196
# 2                    0.669727         89.403196
# 3                    0.669727         89.403196
# 4                    0.669727         89.403196

# %%
# outlier detection using boxplot

numeric_columns = data.select_dtypes(include=np.number).columns.tolist()

plt.figure(figsize=(20, 10))

for i, variable in enumerate(numeric_columns):
    plt.subplot(5, 5, i + 1)
    plt.boxplot(data[variable], whis=1.5)
    plt.tight_layout()
    plt.title(variable)

plt.show()

# %% [markdown]
# ### Modelling

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4625 entries, 0 to 4624
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Engine Capacity                        4625 non-null   int64
#  1   Fuel Type                              4625 non-null   category
#  2   Powertrain                             4625 non-null   category
#  3   Maximum range (Km)                     4625 non-null   float64
#  4   WLTP CO2                               4625 non-null   float64
#  5   Equivalent All Electric Range KM       4625 non-null   float64
#  6   Electric Range City Km                 4625 non-null   float64
#  7   Annual fuel Cost 10000 Miles           4625 non-null   int64
#  8   Annual Electricity cost / 10000 miles  4625 non-null   int64
#  9   Total cost / 10000 miles               4625 non-null   int64
#  10  Noise Level dB(A)                      4625 non-null   float64
#  11  Emissions CO [mg/km]                   4625 non-null   float64
#  12  THC Emissions [mg/km]                  4625 non-null   float64
#  13  Emissions NOx [mg/km]                  4625 non-null   float64
#  14  THC + NOx Emissions [mg/km]            4625 non-null   float64
#  15  Particulates [No.] [mg/km]             4625 non-null   float64
#  16  RDE NOx Combined                       4625 non-null   float64
# dtypes: category(2), float64(11), int64(4)
# memory usage: 551.7 KB

# %%
for col in data.columns:
    if ' ' in col:
        new_col = col.replace(' ', '_')
        data.rename(columns={col: new_col}, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4625 entries, 0 to 4624
# Data columns (total 17 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Engine_Capacity                        4625 non-null   int64
#  1   Fuel_Type                              4625 non-null   category
#  2   Powertrain                             4625 non-null   category
#  3   Maximum_range_(Km)                     4625 non-null   float64
#  4   WLTP_CO2                               4625 non-null   float64
#  5   Equivalent_All_Electric_Range_KM       4625 non-null   float64
#  6   Electric_Range_City_Km                 4625 non-null   float64
#  7   Annual_fuel_Cost_10000_Miles           4625 non-null   int64
#  8   Annual_Electricity_cost_/_10000_miles  4625 non-null   int64
#  9   Total_cost_/_10000_miles               4625 non-null   int64
#  10  Noise_Level_dB(A)                      4625 non-null   float64
#  11  Emissions_CO_[mg/km]                   4625 non-null   float64
#  12  THC_Emissions_[mg/km]                  4625 non-null   float64
#  13  Emissions_NOx_[mg/km]                  4625 non-null   float64
#  14  THC_+_NOx_Emissions_[mg/km]            4625 non-null   float64
#  15  Particulates_[No.]_[mg/km]             4625 non-null   float64
#  16  RDE_NOx_Combined                       4625 non-null   float64
# dtypes: category(2), float64(11), int64(4)
# memory usage: 551.7 KB

# %%
# Separating features and the target column
X = data.drop(["WLTP_CO2"], axis=1)
y = data["WLTP_CO2"]

X = pd.get_dummies(X,drop_first=True)

# %%
# Adding intercept to the dataset
X = sm.add_constant(X)
# Splitting X and y into train and test sets in a 70:30 ratio

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=1
)

# %%
olsmod = sm.OLS(y_train, X_train)
olsres = olsmod.fit()
# let's print the regression summary
print(olsres.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               WLTP_CO2   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.940
# Method:                 Least Squares   F-statistic:                     2105.
# Date:                Wed, 19 Jul 2023   Prob (F-statistic):               0.00
# Time:                        08:16:58   Log-Likelihood:                -13386.
# No. Observations:                3237   AIC:                         2.682e+04
# Df Residuals:                    3212   BIC:                         2.697e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# const                                                16.9062      2.286      7.395      0.000      12.424      21.388
# Engine_Capacity                                       0.0015      0.001      2.345      0.019       0.000       0.003
# Maximum_range_(Km)                                   -0.2268      0.023     -9.690      0.000      -0.273      -0.181
# Equivalent_All_Electric_Range_KM                     -0.0725      0.038     -1.912      0.056      -0.147       0.002
# Electric_Range_City_Km                                0.1853      0.019      9.991      0.000       0.149       0.222
# Annual_fuel_Cost_10000_Miles                         17.0628      2.491      6.851      0.000      12.179      21.946
# Annual_Electricity_cost_/_10000_miles                16.9227      2.492      6.792      0.000      12.037      21.808
# Total_cost_/_10000_miles                            -16.9798      2.491     -6.817      0.000     -21.863     -12.096
# Noise_Level_dB(A)                                    -0.0668      0.023     -2.860      0.004      -0.113      -0.021
# Emissions_CO_[mg/km]                                  0.0060      0.002      2.776      0.006       0.002       0.010
# THC_Emissions_[mg/km]                                -0.0594      0.034     -1.760      0.078      -0.126       0.007
# Emissions_NOx_[mg/km]                                -0.0011      0.028     -0.039      0.969      -0.056       0.054
# THC_+_NOx_Emissions_[mg/km]                           0.1381      0.025      5.420      0.000       0.088       0.188
# Particulates_[No.]_[mg/km]                            1.5243      0.610      2.499      0.012       0.329       2.720
# RDE_NOx_Combined                                     -0.0109      0.011     -0.971      0.331      -0.033       0.011
# Fuel_Type_Diesel Electric                             0.1427      3.229      0.044      0.965      -6.188       6.473
# Fuel_Type_Electricity                                22.6023      4.236      5.336      0.000      14.297      30.907
# Fuel_Type_Electricity / Diesel                       -4.5433      4.799     -0.947      0.344     -13.954       4.867
# Fuel_Type_Electricity / Petrol                       34.0657      2.605     13.075      0.000      28.957      39.174
# Fuel_Type_Petrol                                    -10.4598      1.069     -9.783      0.000     -12.556      -8.363
# Fuel_Type_Petrol / LPG                               57.1213      2.709     21.088      0.000      51.810      62.432
# Fuel_Type_Petrol Electric                            -9.3397      2.744     -3.404      0.001     -14.720      -3.959
# Powertrain_Hybrid Electric Vehicle (HEV)             -9.0101      2.518     -3.578      0.000     -13.948      -4.072
# Powertrain_Internal Combustion Engine (ICE)          -8.6613      1.778     -4.872      0.000     -12.147      -5.176
# Powertrain_Micro-hybrid                              -9.0814      4.614     -1.968      0.049     -18.129      -0.034
# Powertrain_Mild Hybrid Electric Vehicle (MHEV)       -8.4657      2.168     -3.906      0.000     -12.716      -4.216
# Powertrain_Plug-in Hybrid Electric Vehicle (PHEV)    29.5224      3.850      7.668      0.000      21.974      37.071
# ==============================================================================
# Omnibus:                     1850.790   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           430983.376
# Skew:                           1.573   Prob(JB):                         0.00
# Kurtosis:                      59.441   Cond. No.                     1.08e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.96e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Multi-collinearity checks

# %%
# let's check the VIF of the predictors for multicollinearity checks
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_series1 = pd.Series(
    [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])],
    index=X_train.columns,
)
print("VIF values: \n\n{}\n".format(vif_series1))
# Out:
# VIF values:
#
# const                                                0.000000e+00
# Engine_Capacity                                      4.927283e+00
# Maximum_range_(Km)                                   4.597883e+01
# Equivalent_All_Electric_Range_KM                     2.918922e+00
# Electric_Range_City_Km                               5.075588e+01
# Annual_fuel_Cost_10000_Miles                         4.509653e+07
# Annual_Electricity_cost_/_10000_miles                5.026393e+06
# Total_cost_/_10000_miles                             3.181158e+07
# Noise_Level_dB(A)                                    1.738575e+00
# Emissions_CO_[mg/km]                                 2.603470e+00
# THC_Emissions_[mg/km]                                2.092615e+00
# Emissions_NOx_[mg/km]                                2.899042e+00
# THC_+_NOx_Emissions_[mg/km]                          2.375574e+00
# Particulates_[No.]_[mg/km]                           1.172792e+00
# RDE_NOx_Combined                                     1.649389e+00
# Fuel_Type_Diesel Electric                            2.050128e+00
# Fuel_Type_Electricity                                         inf
# Fuel_Type_Electricity / Diesel                                inf
# Fuel_Type_Electricity / Petrol                                inf
# Fuel_Type_Petrol                                     4.011911e+00
# Fuel_Type_Petrol / LPG                               1.350160e+00
# Fuel_Type_Petrol Electric                            1.425514e+01
# Powertrain_Hybrid Electric Vehicle (HEV)                      inf
# Powertrain_Internal Combustion Engine (ICE)                   inf
# Powertrain_Micro-hybrid                                       inf
# Powertrain_Mild Hybrid Electric Vehicle (MHEV)                inf
# Powertrain_Plug-in Hybrid Electric Vehicle (PHEV)             inf
# dtype: float64

# %% [markdown]
# ### 1. Dropping variables with 'inf' VIF due to their high multicollinearity

# %%
# Dropping 'Total_cost_/_10000_miles'
X_train1 = X_train.drop(["Fuel_Type_Electricity", "Fuel_Type_Electricity / Diesel", "Fuel_Type_Electricity / Petrol",
                         "Powertrain_Hybrid Electric Vehicle (HEV)", "Powertrain_Internal Combustion Engine (ICE)",
                         "Powertrain_Micro-hybrid", "Powertrain_Mild Hybrid Electric Vehicle (MHEV)",
                         "Powertrain_Plug-in Hybrid Electric Vehicle (PHEV)"], axis=1)
olsmod_1 = sm.OLS(y_train, X_train1)
olsres_1 = olsmod_1.fit()
print(olsres_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               WLTP_CO2   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.931
# Method:                 Least Squares   F-statistic:                     2734.
# Date:                Wed, 19 Jul 2023   Prob (F-statistic):               0.00
# Time:                        09:03:35   Log-Likelihood:                -13608.
# No. Observations:                3237   AIC:                         2.725e+04
# Df Residuals:                    3220   BIC:                         2.735e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                    16.4543      2.202      7.472      0.000      12.137      20.772
# Engine_Capacity                           0.0034      0.001      5.306      0.000       0.002       0.005
# Maximum_range_(Km)                       -0.0239      0.005     -5.055      0.000      -0.033      -0.015
# Equivalent_All_Electric_Range_KM          0.1626      0.029      5.574      0.000       0.105       0.220
# Annual_fuel_Cost_10000_Miles              0.0793      0.001     77.399      0.000       0.077       0.081
# Annual_Electricity_cost_/_10000_miles    -0.0092      0.002     -4.297      0.000      -0.013      -0.005
# Noise_Level_dB(A)                        -0.0773      0.025     -3.149      0.002      -0.125      -0.029
# Emissions_CO_[mg/km]                      0.0148      0.002      6.586      0.000       0.010       0.019
# THC_Emissions_[mg/km]                    -0.1158      0.035     -3.263      0.001      -0.185      -0.046
# Emissions_NOx_[mg/km]                    -0.0250      0.029     -0.851      0.395      -0.082       0.033
# THC_+_NOx_Emissions_[mg/km]               0.1150      0.027      4.272      0.000       0.062       0.168
# Particulates_[No.]_[mg/km]                1.9040      0.650      2.928      0.003       0.629       3.179
# RDE_NOx_Combined                         -0.0137      0.012     -1.151      0.250      -0.037       0.010
# Fuel_Type_Diesel Electric                -1.8287      2.507     -0.730      0.466      -6.744       3.086
# Fuel_Type_Petrol                        -13.9386      1.117    -12.473      0.000     -16.130     -11.748
# Fuel_Type_Petrol / LPG                   50.2024      2.856     17.580      0.000      44.603      55.801
# Fuel_Type_Petrol Electric               -13.7487      1.237    -11.112      0.000     -16.175     -11.323
# ==============================================================================
# Omnibus:                     2271.099   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           311084.125
# Skew:                           2.433   Prob(JB):                         0.00
# Kurtosis:                      50.779   Cond. No.                     2.95e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.95e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# let's check the VIF of the predictors for multicollinearity checks

vif_series2 = pd.Series(
    [variance_inflation_factor(X_train1.values, i) for i in range(X_train1.shape[1])],
    index=X_train1.columns,
)
print("VIF values: \n\n{}\n".format(vif_series2))
# Out:
# VIF values:
#
# const                                    59.504023
# Engine_Capacity                           4.294285
# Maximum_range_(Km)                        1.644536
# Equivalent_All_Electric_Range_KM          1.511614
# Annual_fuel_Cost_10000_Miles              6.673519
# Annual_Electricity_cost_/_10000_miles     3.273561
# Noise_Level_dB(A)                         1.675489
# Emissions_CO_[mg/km]                      2.466459
# THC_Emissions_[mg/km]                     2.025118
# Emissions_NOx_[mg/km]                     2.733503
# THC_+_NOx_Emissions_[mg/km]               2.319190
# Particulates_[No.]_[mg/km]                1.165169
# RDE_NOx_Combined                          1.625295
# Fuel_Type_Diesel Electric                 1.080051
# Fuel_Type_Petrol                          3.830541
# Fuel_Type_Petrol / LPG                    1.311572
# Fuel_Type_Petrol Electric                 2.532678
# dtype: float64

# %% [markdown]
# ### 2. Dropping 'Annual_fuel_Cost_10000_Miles' column from the model

# %%
X_train2 = X_train1.drop(["Annual_fuel_Cost_10000_Miles"], axis=1)
olsmod_2 = sm.OLS(y_train, X_train2)
olsres_2 = olsmod_2.fit()
print(olsres_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               WLTP_CO2   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     880.2
# Date:                Wed, 19 Jul 2023   Prob (F-statistic):               0.00
# Time:                        09:08:37   Log-Likelihood:                -15309.
# No. Observations:                3237   AIC:                         3.065e+04
# Df Residuals:                    3221   BIC:                         3.075e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                    48.1476      3.659     13.159      0.000      40.974      55.322
# Engine_Capacity                           0.0445      0.001     74.514      0.000       0.043       0.046
# Maximum_range_(Km)                        0.0299      0.008      3.772      0.000       0.014       0.045
# Equivalent_All_Electric_Range_KM         -0.1556      0.049     -3.185      0.001      -0.251      -0.060
# Annual_Electricity_cost_/_10000_miles    -0.0886      0.003    -27.695      0.000      -0.095      -0.082
# Noise_Level_dB(A)                        -0.2178      0.041     -5.262      0.000      -0.299      -0.137
# Emissions_CO_[mg/km]                      0.0508      0.004     13.627      0.000       0.043       0.058
# THC_Emissions_[mg/km]                    -0.3170      0.060     -5.296      0.000      -0.434      -0.200
# Emissions_NOx_[mg/km]                     0.5385      0.048     11.213      0.000       0.444       0.633
# THC_+_NOx_Emissions_[mg/km]               0.0049      0.045      0.108      0.914      -0.084       0.094
# Particulates_[No.]_[mg/km]                8.5013      1.090      7.799      0.000       6.364      10.639
# RDE_NOx_Combined                          0.1913      0.020      9.733      0.000       0.153       0.230
# Fuel_Type_Diesel Electric                 5.1642      4.236      1.219      0.223      -3.141      13.470
# Fuel_Type_Petrol                         10.7439      1.811      5.932      0.000       7.193      14.295
# Fuel_Type_Petrol / LPG                   10.6215      4.751      2.236      0.025       1.306      19.937
# Fuel_Type_Petrol Electric               -13.6574      2.092     -6.528      0.000     -17.760      -9.555
# ==============================================================================
# Omnibus:                     1032.187   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11769.962
# Skew:                           1.180   Prob(JB):                         0.00
# Kurtosis:                      12.039   Cond. No.                     2.14e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# let's check the VIF of the predictors for multicollinearity checks

vif_series2 = pd.Series(
    [variance_inflation_factor(X_train2.values, i) for i in range(X_train2.shape[1])],
    index=X_train2.columns,
)
print("VIF values: \n\n{}\n".format(vif_series2))
# Out:
# VIF values:
#
# const                                    57.446587
# Engine_Capacity                           1.316241
# Maximum_range_(Km)                        1.609088
# Equivalent_All_Electric_Range_KM          1.481598
# Annual_Electricity_cost_/_10000_miles     2.530378
# Noise_Level_dB(A)                         1.666326
# Emissions_CO_[mg/km]                      2.361563
# THC_Emissions_[mg/km]                     2.014256
# Emissions_NOx_[mg/km]                     2.564966
# THC_+_NOx_Emissions_[mg/km]               2.312714
# Particulates_[No.]_[mg/km]                1.145146
# RDE_NOx_Combined                          1.545057
# Fuel_Type_Diesel Electric                 1.078648
# Fuel_Type_Petrol                          3.518594
# Fuel_Type_Petrol / LPG                    1.269511
# Fuel_Type_Petrol Electric                 2.532676
# dtype: float64

# %% [markdown]
# **Observations**
#
# 1. Since the VIF are less than 5, we have no effect of multicollinearity. We can also trust the p-values to remove insignificant predictors.
# 2. We will now remove insignificant predictors

# %% [markdown]
# ### 3. Dropping 'THC_+_NOx_Emissions_[mg/km]' column from the model

# %%
X_train3 = X_train2.drop(["THC_+_NOx_Emissions_[mg/km]"], axis=1)
olsmod_3 = sm.OLS(y_train, X_train3)
olsres_3 = olsmod_3.fit()
print(olsres_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               WLTP_CO2   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     943.3
# Date:                Wed, 19 Jul 2023   Prob (F-statistic):               0.00
# Time:                        09:32:40   Log-Likelihood:                -15309.
# No. Observations:                3237   AIC:                         3.065e+04
# Df Residuals:                    3222   BIC:                         3.074e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                    48.2051      3.619     13.320      0.000      41.109      55.301
# Engine_Capacity                           0.0445      0.001     74.609      0.000       0.043       0.046
# Maximum_range_(Km)                        0.0298      0.008      3.785      0.000       0.014       0.045
# Equivalent_All_Electric_Range_KM         -0.1560      0.049     -3.207      0.001      -0.251      -0.061
# Annual_Electricity_cost_/_10000_miles    -0.0886      0.003    -27.923      0.000      -0.095      -0.082
# Noise_Level_dB(A)                        -0.2166      0.040     -5.417      0.000      -0.295      -0.138
# Emissions_CO_[mg/km]                      0.0508      0.004     13.629      0.000       0.043       0.058
# THC_Emissions_[mg/km]                    -0.3166      0.060     -5.301      0.000      -0.434      -0.199
# Emissions_NOx_[mg/km]                     0.5410      0.042     12.900      0.000       0.459       0.623
# Particulates_[No.]_[mg/km]                8.5018      1.090      7.801      0.000       6.365      10.639
# RDE_NOx_Combined                          0.1915      0.020      9.800      0.000       0.153       0.230
# Fuel_Type_Diesel Electric                 5.1792      4.233      1.224      0.221      -3.121      13.479
# Fuel_Type_Petrol                         10.7228      1.800      5.956      0.000       7.193      14.252
# Fuel_Type_Petrol / LPG                   10.6066      4.748      2.234      0.026       1.297      19.916
# Fuel_Type_Petrol Electric               -13.6555      2.092     -6.528      0.000     -17.757      -9.554
# ==============================================================================
# Omnibus:                     1032.045   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11777.073
# Skew:                           1.180   Prob(JB):                         0.00
# Kurtosis:                      12.042   Cond. No.                     2.14e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Observations**
#
# 1. There isn't a significant drop in the adjusted r-square

# %% [markdown]
# ### 4. Dropping 'Fuel_Type_Diesel Electric' column from the training set

# %%
X_train4 = X_train3.drop(["Fuel_Type_Diesel Electric"], axis=1)
olsmod_4 = sm.OLS(y_train, X_train4)
olsres_4 = olsmod_4.fit()
print(olsres_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               WLTP_CO2   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     1016.
# Date:                Wed, 19 Jul 2023   Prob (F-statistic):               0.00
# Time:                        09:33:52   Log-Likelihood:                -15310.
# No. Observations:                3237   AIC:                         3.065e+04
# Df Residuals:                    3223   BIC:                         3.073e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                    48.7784      3.589     13.592      0.000      41.742      55.815
# Engine_Capacity                           0.0445      0.001     74.603      0.000       0.043       0.046
# Maximum_range_(Km)                        0.0298      0.008      3.792      0.000       0.014       0.045
# Equivalent_All_Electric_Range_KM         -0.1554      0.049     -3.194      0.001      -0.251      -0.060
# Annual_Electricity_cost_/_10000_miles    -0.0892      0.003    -28.480      0.000      -0.095      -0.083
# Noise_Level_dB(A)                        -0.2138      0.040     -5.356      0.000      -0.292      -0.136
# Emissions_CO_[mg/km]                      0.0511      0.004     13.726      0.000       0.044       0.058
# THC_Emissions_[mg/km]                    -0.3182      0.060     -5.329      0.000      -0.435      -0.201
# Emissions_NOx_[mg/km]                     0.5351      0.042     12.843      0.000       0.453       0.617
# Particulates_[No.]_[mg/km]                8.4760      1.090      7.778      0.000       6.339      10.613
# RDE_NOx_Combined                          0.1894      0.019      9.730      0.000       0.151       0.228
# Fuel_Type_Petrol                         10.2061      1.750      5.832      0.000       6.775      13.638
# Fuel_Type_Petrol / LPG                   10.0281      4.725      2.122      0.034       0.764      19.292
# Fuel_Type_Petrol Electric               -14.2159      2.041     -6.965      0.000     -18.218     -10.214
# ==============================================================================
# Omnibus:                     1037.248   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11930.374
# Skew:                           1.185   Prob(JB):                         0.00
# Kurtosis:                      12.102   Cond. No.                     2.07e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.07e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Observations**
#
# 1. There is no significant drop in the adjusted r-square and no variable with p-value above 5. This model with the above features will be selected.

# %% [markdown]
# ## Test for Linearity and Independence by making a plot of fitted values vs residuals

# %%
df_pred = pd.DataFrame()

df_pred["Actual Values"] = y_train.values.flatten()  # actual values
df_pred["Fitted Values"] = olsres_4.fittedvalues.values  # predicted values
df_pred["Residuals"] = olsres_4.resid.values  # residuals

df_pred.head()
# Out:
#    Actual Values  Fitted Values  Residuals
# 0      137.00000     127.328970   9.671030
# 1      170.00000     143.184143  26.815857
# 2      149.13952      55.837204  93.302316
# 3      149.00000     171.002442 -22.002442
# 4      306.00000     325.880995 -19.880995

# %%
# plotting the fitted values vs residuals

sns.set_style("whitegrid")
sns.residplot(
    data=df_pred, x="Fitted Values", y="Residuals", color="purple", lowess=True
)
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.title("Fitted vs Residual plot")
plt.show()

# %% [markdown]
# **Observation**
#
# * The pattern and data points seems to be randomly distributed.
# * The linearity and Independence test has been passed by the model.

# %% [markdown]
# ## Test for Normality by plotting the distribution of the residuals and Q-Q Plot

# %%
# Plotting the distribution of the residuals

sns.histplot(df_pred["Residuals"], kde=True)
plt.title("Normality of residuals")
plt.show()

# %%
# Performing a Q-Q plot of the residuals

import pylab
import scipy.stats as stats

stats.probplot(df_pred["Residuals"], dist="norm", plot=pylab)
plt.show()

# %% [markdown]
# Observation
#
# * The residual distribution plot shows that the residuals are normally distributed
# * Most of the points are lying on the straight line in QQ plot
# * In conclusion, the fitted model has passed the normality test

# %% [markdown]
# ### Test for Homoscedasticity using the The null and alternate hypotheses of the goldfeldquandt test are as follows:
#
# * Null hypothesis : Residuals are homoscedastic
# * Alternate hypothesis : Residuals have hetroscedasticity

# %%
import statsmodels.stats.api as sms
from statsmodels.compat import lzip

name = ["F statistic", "p-value"]
test = sms.het_goldfeldquandt(df_pred["Residuals"], X_train)
lzip(name, test)
# Out:
# [('F statistic', 0.8921235921763075), ('p-value', 0.988660667094167)]

# %% [markdown]
# **Observation**
#
# * Since p-value > 0.05 we can say that the residuals are homoscedastic. The fitted model has passed the homoscedastic test.
# * Also, the predictor variables have their p-values below 0.05 and the linear model assumption has been passed. We therefore adopt olsres_4 model as the final model for prediction

# %% [markdown]
# ## Final Model

# %%
# printing the summary of the accepted model

print(olsres_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               WLTP_CO2   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     1016.
# Date:                Wed, 19 Jul 2023   Prob (F-statistic):               0.00
# Time:                        09:50:00   Log-Likelihood:                -15310.
# No. Observations:                3237   AIC:                         3.065e+04
# Df Residuals:                    3223   BIC:                         3.073e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                    48.7784      3.589     13.592      0.000      41.742      55.815
# Engine_Capacity                           0.0445      0.001     74.603      0.000       0.043       0.046
# Maximum_range_(Km)                        0.0298      0.008      3.792      0.000       0.014       0.045
# Equivalent_All_Electric_Range_KM         -0.1554      0.049     -3.194      0.001      -0.251      -0.060
# Annual_Electricity_cost_/_10000_miles    -0.0892      0.003    -28.480      0.000      -0.095      -0.083
# Noise_Level_dB(A)                        -0.2138      0.040     -5.356      0.000      -0.292      -0.136
# Emissions_CO_[mg/km]                      0.0511      0.004     13.726      0.000       0.044       0.058
# THC_Emissions_[mg/km]                    -0.3182      0.060     -5.329      0.000      -0.435      -0.201
# Emissions_NOx_[mg/km]                     0.5351      0.042     12.843      0.000       0.453       0.617
# Particulates_[No.]_[mg/km]                8.4760      1.090      7.778      0.000       6.339      10.613
# RDE_NOx_Combined                          0.1894      0.019      9.730      0.000       0.151       0.228
# Fuel_Type_Petrol                         10.2061      1.750      5.832      0.000       6.775      13.638
# Fuel_Type_Petrol / LPG                   10.0281      4.725      2.122      0.034       0.764      19.292
# Fuel_Type_Petrol Electric               -14.2159      2.041     -6.965      0.000     -18.218     -10.214
# ==============================================================================
# Omnibus:                     1037.248   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11930.374
# Skew:                           1.185   Prob(JB):                         0.00
# Kurtosis:                      12.102   Cond. No.                     2.07e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.07e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Observations
#
# * R-squared of the model is 0.804 and adjusted R-squared is 0.803, which shows that the model is able to explain ~80% variance in the data. This is quite good.

# %% [markdown]
# ## Predictions

# %%
# let's check the model parameters

olsres_4.params
# Out:
# const                                    48.778363
# Engine_Capacity                           0.044508
# Maximum_range_(Km)                        0.029838
# Equivalent_All_Electric_Range_KM         -0.155404
# Annual_Electricity_cost_/_10000_miles    -0.089228
# Noise_Level_dB(A)                        -0.213831
# Emissions_CO_[mg/km]                      0.051072
# THC_Emissions_[mg/km]                    -0.318185
# Emissions_NOx_[mg/km]                     0.535116
# Particulates_[No.]_[mg/km]                8.475957
# RDE_NOx_Combined                          0.189402
# Fuel_Type_Petrol                         10.206133
# Fuel_Type_Petrol / LPG                   10.028081
# Fuel_Type_Petrol Electric               -14.215944
# dtype: float64

# %%
# Let us write the equation of linear regression

Equation = "WLTP_CO2 ="
print(Equation, end=" ")
for i in range(len(X_train4.columns)):
    if i == 0:
        print(olsres_4.params[i], "+", end=" ")
    elif i != len(X_train4.columns) - 1:
        print(
            olsres_4.params[i],
            "* (",
            X_train4.columns[i],
            ")",
            "+",
            end="  ",
        )
    else:
        print(olsres_4.params[i], "* (", X_train4.columns[i], ")")
# Out:
# WLTP_CO2 = 48.77836279728263 + 0.044507690009333654 * ( Engine_Capacity ) +  0.029838270599375265 * ( Maximum_range_(Km) ) +  -0.1554040568429409 * ( Equivalent_All_Electric_Range_KM ) +  -0.08922804757732786 * ( Annual_Electricity_cost_/_10000_miles ) +  -0.2138307219918335 * ( Noise_Level_dB(A) ) +  0.051071838432338965 * ( Emissions_CO_[mg/km] ) +  -0.31818533018865375 * ( THC_Emissions_[mg/km] ) +  0.5351160009591771 * ( Emissions_NOx_[mg/km] ) +  8.475956625760952 * ( Particulates_[No.]_[mg/km] ) +  0.18940179304360336 * ( RDE_NOx_Combined ) +  10.206132606416293 * ( Fuel_Type_Petrol ) +  10.02808136267752 * ( Fuel_Type_Petrol / LPG ) +  -14.215944287386876 * ( Fuel_Type_Petrol Electric )

# %% [markdown]
# ### Making predictions on the test data.

# %%
# Identify columns in the training and test dataset
train_columns = set(X_train4.columns)
test_columns = set(X_test.columns)

# Compare columns
columns_to_drop = test_columns - train_columns

# Drop columns from the test dataset
X_test.drop(columns=columns_to_drop, inplace=True)

# %%
# Making predictions on the test set

y_pred = olsres_4.predict(X_test)
rmse1 = np.sqrt(mean_squared_error(y_train, df_pred["Fitted Values"]))
rmse1
# Out:
# 27.404040538873335

# %%
# let's check the RMSE on the test data

rmse2 = np.sqrt(mean_squared_error(y_test, y_pred))
rmse2
# Out:
# 25.943808324080077

# %% [markdown]
# **Observation**
#
# * The RMSE on the train and test sets are comparable. So, our model is not suffering from overfitting.
# * We can conclude the model "ols_res4" is good for prediction as well as inference purposes.
